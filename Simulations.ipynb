# %%
import simpy
import numpy as np

class Server:
    def __init__(self, env):
        self.env = env
        self.machine = simpy.Resource(env, capacity=1)
        self.latest_task_end_time = 0

    def process(self, task):
        with self.machine.request() as req:
            yield req
            yield self.env.timeout(task.duration)
            self.latest_task_end_time = self.env.now

class Task:
    def __init__(self, duration):
        self.duration = duration

class FitnessFunction:
    def __init__(self, tasks):
        self.tasks = tasks

    def __call__(self, solution):
        env = simpy.Environment()
        servers = [Server(env) for _ in range(10)]

        for task_duration, server_index in zip(self.tasks, solution):
            task = Task(task_duration)
            server = servers[int(server_index)]
            env.process(server.process(task))

        env.run()

        makespan = max(server.latest_task_end_time for server in servers)
        return makespan

class Flower:
    def __init__(self, decision_variables, lower_bound, upper_bound):
        self.position = np.random.uniform(low=lower_bound, high=upper_bound, size=decision_variables)
        self.fitness = float('inf')

class FlowerPollination:
    def __init__(self, fitness_function, population_size=20, decision_variables=10, lower_bound=0, upper_bound=1, generations=100, switch_prob=0.8, gamma=0.1, beta=1.5):
        self.population = [Flower(decision_variables, lower_bound, upper_bound) for _ in range(population_size)]
        self.global_best = None
        self.fitness_function = fitness_function
        self.population_size = population_size
        self.decision_variables = decision_variables
        self.lower_bound = lower_bound
        self.upper_bound = upper_bound
        self.generations = generations
        self.switch_prob = switch_prob
        self.gamma = gamma
        self.beta = beta

    def levy_flight(self, beta):
        sigma = (np.math.gamma(1 + beta) * np.sin(np.pi * beta / 2) / (np.math.gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))) ** (1 / beta)
        u = np.random.normal(0, sigma, size=self.decision_variables)
        v = np.random.normal(0, 1, size=self.decision_variables)
        step = u / abs(v) ** (1 / beta)
        return step

    def global_pollination(self, flower):
        step_size = self.gamma * self.levy_flight(self.beta)
        new_position = flower.position + step_size * (flower.position - self.global_best.position)
        return new_position

    def local_pollination(self, flower):
        flower_j = np.random.choice(self.population)
        epsilon = np.random.uniform(low=0, high=1, size=self.decision_variables)
        new_position = flower.position + epsilon * (flower_j.position - flower.position)
        return new_position

    def pollination(self, flower):
        r = np.random.uniform(low=0, high=1)
        if r < self.switch_prob:
            new_position = self.global_pollination(flower)
        else:
            new_position = self.local_pollination(flower)
        return np.clip(new_position, self.lower_bound, self.upper_bound)

    def find_global_best(self):
        for flower in self.population:
            if flower.fitness < self.global_best.fitness:
                self.global_best = flower

    def optimize(self):
        self.global_best = self.population[0]
        self.global_best.fitness = self.fitness_function(self.global_best.position)

        for g in range(self.generations):
            for flower in self.population:
                flower.fitness = self.fitness_function(flower.position)
                self.find_global_best()

                new_position = self.pollination(flower)
                new_fitness = self.fitness_function(new_position)

                if new_fitness < flower.fitness:
                    flower.position = new_position
                    flower.fitness = new_fitness

            self.find_global_best()
            print(f"Generation: {g}, Best fitness: {self.global_best.fitness}")

        return self.global_best

class SimulatedAnnealing:
    def __init__(self, fitness_function, initial_solution, initial_temperature, cooling_rate):
        self.fitness_function = fitness_function
        self.current_solution = initial_solution
        self.current_fitness = self.fitness_function(self.current_solution)
        self.temperature = initial_temperature
        self.cooling_rate = cooling_rate

    def neighbour(self):
        new_solution = self.current_solution.copy()
        task_index = np.random.randint(0, len(new_solution))
        new_solution[task_index] = np.random.uniform(low=0, high=9)
        return new_solution

    def accept(self, candidate_fitness):
        if candidate_fitness < self.current_fitness:
            return True
        else:
            return np.random.rand() < np.exp((self.current_fitness - candidate_fitness) / self.temperature)

    def anneal(self):
        while self.temperature > 0.001:
            candidate_solution = self.neighbour()
            candidate_fitness = self.fitness_function(candidate_solution)

            if self.accept(candidate_fitness):
                self.current_solution = candidate_solution
                self.current_fitness = candidate_fitness

            self.temperature *= self.cooling_rate
            print(f"Temperature: {self.temperature}, Current fitness: {self.current_fitness}")

        return self.current_solution

def generate_schedule(task_sizes):
    for task_size in task_sizes:
        task_durations = np.random.uniform(low=1, high=10, size=task_size)
        fitness_function = FitnessFunction(task_durations)

        fpa = FlowerPollination(fitness_function, population_size=100, decision_variables=task_size, lower_bound=0, upper_bound=9, generations=50)
        best_solution = fpa.optimize()
        print(f"Task size: {task_size}, Best makespan (FPA): {best_solution.fitness}")

        sa = SimulatedAnnealing(fitness_function, best_solution.position, initial_temperature=10, cooling_rate=0.9)
        best_solution_sa = sa.anneal()
        print(f"Task size: {task_size}, Best makespan (SA): {fitness_function(best_solution_sa)}")

task_sizes = [200]
generate_schedule(task_sizes)
# Out:
# Generation: 0, Best fitness: 129.20929246154336
# Generation: 1, Best fitness: 129.20929246154336
# Generation: 2, Best fitness: 129.20929246154336
# Generation: 3, Best fitness: 129.20929246154336
# Generation: 4, Best fitness: 127.96466573142229
# Generation: 5, Best fitness: 127.96466573142229
# Generation: 6, Best fitness: 127.96466573142229
# Generation: 7, Best fitness: 127.96466573142229
# Generation: 8, Best fitness: 127.96466573142229
# Generation: 9, Best fitness: 127.96466573142229
# Generation: 10, Best fitness: 127.96466573142229
# Generation: 11, Best fitness: 127.96466573142229
# Generation: 12, Best fitness: 127.96466573142229
# Generation: 13, Best fitness: 127.96466573142229
# Generation: 14, Best fitness: 127.96466573142229
# Generation: 15, Best fitness: 127.96466573142229
# Generation: 16, Best fitness: 124.666720032731
# Generation: 17, Best fitness: 124.666720032731
# Generation: 18, Best fitness: 124.666720032731
# Generation: 19, Best fitness: 124.666720032731
# Generation: 20, Best fitness: 124.666720032731
# Generation: 21, Best fitness: 124.666720032731
# Generation: 22, Best fitness: 124.666720032731
# Generation: 23, Best fitness: 124.666720032731
# Generation: 24, Best fitness: 124.666720032731
# Generation: 25, Best fitness: 124.666720032731
# Generation: 26, Best fitness: 124.666720032731
# Generation: 27, Best fitness: 124.666720032731
# Generation: 28, Best fitness: 124.666720032731
# Generation: 29, Best fitness: 124.666720032731
# Generation: 30, Best fitness: 124.666720032731
# Generation: 31, Best fitness: 124.666720032731
# Generation: 32, Best fitness: 124.666720032731
# Generation: 33, Best fitness: 124.666720032731
# Generation: 34, Best fitness: 121.66672382276892
# Generation: 35, Best fitness: 121.66672382276892
# Generation: 36, Best fitness: 121.66672382276892
# Generation: 37, Best fitness: 121.66672382276892
# Generation: 38, Best fitness: 121.66672382276892
# Generation: 39, Best fitness: 121.66672382276892
# Generation: 40, Best fitness: 121.66672382276892
# Generation: 41, Best fitness: 121.66672382276892
# Generation: 42, Best fitness: 121.66672382276892
# Generation: 43, Best fitness: 121.66672382276892
# Generation: 44, Best fitness: 121.66672382276892
# Generation: 45, Best fitness: 121.66672382276892
# Generation: 46, Best fitness: 121.66672382276892
# Generation: 47, Best fitness: 121.66672382276892
# Generation: 48, Best fitness: 121.66672382276892
# Generation: 49, Best fitness: 121.66202057363544
# Task size: 200, Best makespan (FPA): 121.66202057363544
# Temperature: 9.0, Current fitness: 126.40176234622609
# Temperature: 8.1, Current fitness: 126.40176234622609
# Temperature: 7.29, Current fitness: 128.69560458255143
# Temperature: 6.561, Current fitness: 129.22393000291996
# Temperature: 5.9049000000000005, Current fitness: 129.22393000291996
# Temperature: 5.3144100000000005, Current fitness: 129.22393000291996
# Temperature: 4.7829690000000005, Current fitness: 129.22393000291996
# Temperature: 4.3046721, Current fitness: 129.22393000291996
# Temperature: 3.8742048900000006, Current fitness: 129.22393000291996
# Temperature: 3.4867844010000004, Current fitness: 131.1408074465188
# Temperature: 3.1381059609000004, Current fitness: 131.1408074465188
# Temperature: 2.82429536481, Current fitness: 131.1408074465188
# Temperature: 2.541865828329, Current fitness: 131.1408074465188
# Temperature: 2.2876792454961, Current fitness: 131.1408074465188
# Temperature: 2.05891132094649, Current fitness: 131.1408074465188
# Temperature: 1.853020188851841, Current fitness: 131.1408074465188
# Temperature: 1.6677181699666568, Current fitness: 131.1408074465188
# Temperature: 1.5009463529699911, Current fitness: 131.1408074465188
# Temperature: 1.350851717672992, Current fitness: 125.23440418016708
# Temperature: 1.2157665459056928, Current fitness: 125.23440418016708
# Temperature: 1.0941898913151236, Current fitness: 125.23440418016708
# Temperature: 0.9847709021836112, Current fitness: 125.23440418016708
# Temperature: 0.88629381196525, Current fitness: 125.23440418016708
# Temperature: 0.7976644307687251, Current fitness: 125.23440418016708
# Temperature: 0.7178979876918525, Current fitness: 125.23440418016708
# Temperature: 0.6461081889226673, Current fitness: 125.23440418016708
# Temperature: 0.5814973700304006, Current fitness: 125.23440418016708
# Temperature: 0.5233476330273605, Current fitness: 123.57664536163773
# Temperature: 0.47101286972462447, Current fitness: 123.57664536163773
# Temperature: 0.423911582752162, Current fitness: 123.57664536163773
# Temperature: 0.38152042447694584, Current fitness: 123.57664536163773
# Temperature: 0.34336838202925124, Current fitness: 123.57664536163773
# Temperature: 0.30903154382632614, Current fitness: 123.57664536163773
# Temperature: 0.27812838944369356, Current fitness: 123.57664536163773
# Temperature: 0.2503155504993242, Current fitness: 123.57664536163773
# Temperature: 0.2252839954493918, Current fitness: 123.57664536163773
# Temperature: 0.2027555959044526, Current fitness: 123.57664536163773
# Temperature: 0.18248003631400736, Current fitness: 123.57688729022519
# Temperature: 0.16423203268260664, Current fitness: 123.57688729022519
# Temperature: 0.14780882941434598, Current fitness: 123.57688729022519
# Temperature: 0.13302794647291138, Current fitness: 123.57688729022519
# Temperature: 0.11972515182562025, Current fitness: 123.57688729022519
# Temperature: 0.10775263664305823, Current fitness: 123.57688729022519
# Temperature: 0.0969773729787524, Current fitness: 123.57688729022519
# Temperature: 0.08727963568087717, Current fitness: 123.57688729022519
# Temperature: 0.07855167211278945, Current fitness: 123.57688729022519
# Temperature: 0.0706965049015105, Current fitness: 123.57688729022519
# Temperature: 0.06362685441135946, Current fitness: 123.57688729022519
# Temperature: 0.05726416897022351, Current fitness: 123.57688729022519
# Temperature: 0.05153775207320116, Current fitness: 123.57688729022519
# Temperature: 0.04638397686588105, Current fitness: 123.57688729022519
# Temperature: 0.041745579179292946, Current fitness: 123.57688729022519
# Temperature: 0.037571021261363656, Current fitness: 123.57688729022519
# Temperature: 0.03381391913522729, Current fitness: 123.57688729022519
# Temperature: 0.030432527221704565, Current fitness: 123.52991140400863
# Temperature: 0.02738927449953411, Current fitness: 123.52991140400863
# Temperature: 0.0246503470495807, Current fitness: 123.49953008179247
# Temperature: 0.02218531234462263, Current fitness: 123.49953008179247
# Temperature: 0.01996678111016037, Current fitness: 123.49953008179247
# Temperature: 0.017970102999144335, Current fitness: 122.73478884076515
# Temperature: 0.016173092699229903, Current fitness: 122.73478884076515
# Temperature: 0.014555783429306914, Current fitness: 122.73478884076515
# Temperature: 0.013100205086376222, Current fitness: 121.69228020022472
# Temperature: 0.0117901845777386, Current fitness: 121.69228020022472
# Temperature: 0.010611166119964741, Current fitness: 119.87365037861913
# Temperature: 0.009550049507968268, Current fitness: 119.87365037861913
# Temperature: 0.00859504455717144, Current fitness: 119.87365037861913
# Temperature: 0.007735540101454296, Current fitness: 119.87365037861913
# Temperature: 0.006961986091308867, Current fitness: 119.87365037861913
# Temperature: 0.00626578748217798, Current fitness: 119.87365037861913
# Temperature: 0.005639208733960182, Current fitness: 119.87365037861913
# Temperature: 0.005075287860564165, Current fitness: 119.87365037861913
# Temperature: 0.004567759074507748, Current fitness: 119.87365037861913
# Temperature: 0.004110983167056974, Current fitness: 119.87365037861913
# Temperature: 0.0036998848503512764, Current fitness: 119.87365037861913
# Temperature: 0.003329896365316149, Current fitness: 119.87365037861913
# Temperature: 0.002996906728784534, Current fitness: 119.87365037861913
# Temperature: 0.0026972160559060807, Current fitness: 119.87365037861913
# Temperature: 0.0024274944503154725, Current fitness: 119.56999105020051
# Temperature: 0.0021847450052839253, Current fitness: 119.56999105020051
# Temperature: 0.001966270504755533, Current fitness: 119.56999105020051
# Temperature: 0.0017696434542799797, Current fitness: 119.56999105020051
# Temperature: 0.0015926791088519817, Current fitness: 119.56999105020051
# Temperature: 0.0014334111979667837, Current fitness: 119.56999105020051
# Temperature: 0.0012900700781701053, Current fitness: 119.56999105020051
# Temperature: 0.0011610630703530948, Current fitness: 119.56999105020051
# Temperature: 0.0010449567633177854, Current fitness: 119.56999105020051
# Temperature: 0.0009404610869860069, Current fitness: 119.56999105020051
# Task size: 200, Best makespan (SA): 119.56999105020051

# %%
import simpy
import numpy as np

class Server:
    def __init__(self, env):
        self.env = env
        self.machine = simpy.Resource(env, capacity=1)
        self.latest_task_end_time = 0

    def process(self, task):
        with self.machine.request() as req:
            yield req
            yield self.env.timeout(task.duration)
            self.latest_task_end_time = self.env.now

class Task:
    def __init__(self, duration):
        self.duration = duration

class FitnessFunction:
    def __init__(self, tasks):
        self.tasks = tasks

    def __call__(self, solution):
        env = simpy.Environment()
        servers = [Server(env) for _ in range(10)]

        for task_duration, server_index in zip(self.tasks, solution):
            task = Task(task_duration)
            server = servers[int(server_index)]
            env.process(server.process(task))

        env.run()

        makespan = max(server.latest_task_end_time for server in servers)
        return makespan

class Flower:
    def __init__(self, decision_variables, lower_bound, upper_bound):
        self.position = np.random.uniform(low=lower_bound, high=upper_bound, size=decision_variables)
        self.fitness = float('inf')

class SimulatedAnnealing:
    def __init__(self, fitness_function, initial_solution, initial_temperature, cooling_rate):
        self.fitness_function = fitness_function
        self.current_solution = initial_solution
        self.current_fitness = self.fitness_function(self.current_solution)
        self.temperature = initial_temperature
        self.cooling_rate = cooling_rate

    def accept(self, candidate_fitness):
        if candidate_fitness < self.current_fitness:
            return True
        else:
            return np.random.rand() < np.exp((self.current_fitness - candidate_fitness) / self.temperature)

class FlowerPollination:
    def __init__(self, fitness_function, population_size=20, decision_variables=10, lower_bound=0, upper_bound=1, generations=100, switch_prob=0.8, gamma=0.1, beta=1.5):
        self.population = [Flower(decision_variables, lower_bound, upper_bound) for _ in range(population_size)]
        self.global_best = None
        self.fitness_function = fitness_function
        self.population_size = population_size
        self.decision_variables = decision_variables
        self.lower_bound = lower_bound
        self.upper_bound = upper_bound
        self.generations = generations
        self.switch_prob = switch_prob
        self.gamma = gamma
        self.beta = beta

    def levy_flight(self, beta):
        sigma = (np.math.gamma(1 + beta) * np.sin(np.pi * beta / 2) / (np.math.gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))) ** (1 / beta)
        u = np.random.normal(0, sigma, size=self.decision_variables)
        v = np.random.normal(0, 1, size=self.decision_variables)
        step = u / abs(v) ** (1 / beta)
        return step

    def global_pollination(self, flower):
        step_size = self.gamma * self.levy_flight(self.beta)
        new_position = flower.position + step_size * (flower.position - self.global_best.position)
        return new_position

    def local_pollination(self, flower):
        flower_j = np.random.choice(self.population)
        epsilon = np.random.uniform(low=0, high=1, size=self.decision_variables)
        new_position = flower.position + epsilon * (flower_j.position - flower.position)
        return new_position

    def pollination(self, flower):
        r = np.random.uniform(low=0, high=1)
        if r < self.switch_prob:
            new_position = self.global_pollination(flower)
        else:
            new_position = self.local_pollination(flower)
        return np.clip(new_position, self.lower_bound, self.upper_bound)

    def find_global_best(self):
        for flower in self.population:
            if flower.fitness < self.global_best.fitness:
                self.global_best = flower

    def optimize(self):
        self.global_best = self.population[0]
        self.global_best.fitness = self.fitness_function(self.global_best.position)
        sa = SimulatedAnnealing(self.fitness_function, self.global_best.position, initial_temperature=10, cooling_rate=0.9)

        for g in range(self.generations):
            for flower in self.population:
                flower.fitness = self.fitness_function(flower.position)
                self.find_global_best()

                new_position = self.pollination(flower)
                new_fitness = self.fitness_function(new_position)

                if sa.accept(new_fitness):
                    flower.position = new_position
                    flower.fitness = new_fitness

            self.find_global_best()
            print(f"Generation: {g}, Best fitness: {self.global_best.fitness}")

        return self.global_best

def generate_schedule(task_sizes):
    for task_size in task_sizes:
        task_durations = np.random.uniform(low=1, high=10, size=task_size)
        fitness_function = FitnessFunction(task_durations)

        fpa = FlowerPollination(fitness_function, population_size=100, decision_variables=task_size, lower_bound=0, upper_bound=9, generations=50)
        best_solution = fpa.optimize()
        print(f"Task size: {task_size}, Best makespan (Hybrid FPA-SA): {best_solution.fitness}")

task_sizes = [200]
generate_schedule(task_sizes)
# Out:
# Generation: 0, Best fitness: 132.5839104906782
# Generation: 1, Best fitness: 130.4893766852978
# Generation: 2, Best fitness: 126.64546995477377
# Generation: 3, Best fitness: 126.64546995477377
# Generation: 4, Best fitness: 126.64546995477377
# Generation: 5, Best fitness: 129.10326079658228
# Generation: 6, Best fitness: 129.10326079658228
# Generation: 7, Best fitness: 129.10326079658228
# Generation: 8, Best fitness: 129.10326079658228
# Generation: 9, Best fitness: 129.10326079658228
# Generation: 10, Best fitness: 129.10326079658228
# Generation: 11, Best fitness: 129.10326079658228
# Generation: 12, Best fitness: 129.10326079658228
# Generation: 13, Best fitness: 129.10326079658228
# Generation: 14, Best fitness: 129.10326079658228
# Generation: 15, Best fitness: 129.10326079658228
# Generation: 16, Best fitness: 129.10326079658228
# Generation: 17, Best fitness: 129.10326079658228
# Generation: 18, Best fitness: 129.10326079658228
# Generation: 19, Best fitness: 129.10326079658228
# Generation: 20, Best fitness: 135.79784832829878
# Generation: 21, Best fitness: 130.29646762967263
# Generation: 22, Best fitness: 130.29646762967263
# Generation: 23, Best fitness: 130.29646762967263
# Generation: 24, Best fitness: 130.29646762967263
# Generation: 25, Best fitness: 125.89469477277831
# Generation: 26, Best fitness: 125.89469477277831
# Generation: 27, Best fitness: 125.89469477277831
# Generation: 28, Best fitness: 125.89469477277831
# Generation: 29, Best fitness: 125.89469477277831
# Generation: 30, Best fitness: 125.89469477277831
# Generation: 31, Best fitness: 125.89469477277831
# Generation: 32, Best fitness: 131.99969988401938
# Generation: 33, Best fitness: 131.99969988401938
# Generation: 34, Best fitness: 131.99969988401938
# Generation: 35, Best fitness: 131.99969988401938
# Generation: 36, Best fitness: 131.99969988401938
# Generation: 37, Best fitness: 131.99969988401938
# Generation: 38, Best fitness: 131.99969988401938
# Generation: 39, Best fitness: 131.99969988401938
# Generation: 40, Best fitness: 131.99969988401938
# Generation: 41, Best fitness: 131.99969988401938
# Generation: 42, Best fitness: 131.99969988401938
# Generation: 43, Best fitness: 130.83023860201556
# Generation: 44, Best fitness: 130.83023860201556
# Generation: 45, Best fitness: 130.83023860201556
# Generation: 46, Best fitness: 130.83023860201556
# Generation: 47, Best fitness: 130.83023860201556
# Generation: 48, Best fitness: 130.83023860201556
# Generation: 49, Best fitness: 130.83023860201556
# Task size: 200, Best makespan (Hybrid FPA-SA): 130.83023860201556

# %%
import simpy
import numpy as np

class Server:
    def __init__(self, env, speed=1):
        self.env = env
        self.machine = simpy.Resource(env, capacity=1)
        self.latest_task_end_time = 0
        self.speed = speed
        self.expected_end_time = 0

    def process(self, task):
        with self.machine.request() as req:
            yield req
            yield self.env.timeout(task.duration / self.speed)
            self.latest_task_end_time = self.env.now
            self.expected_end_time = self.env.now + task.duration / self.speed


class Task:
    def __init__(self, duration):
        self.duration = duration

class FitnessFunction:
    def __init__(self, tasks, servers):
        self.tasks = tasks
        self.servers = servers

    def __call__(self, solution):
        env = simpy.Environment()
        servers = [Server(env, speed=speed) for speed in self.servers]

        for task_duration, server_index in zip(self.tasks, solution):
            task = Task(task_duration)
            server = servers[int(server_index)]
            env.process(server.process(task))

        env.run()

        makespan = max(server.latest_task_end_time for server in servers)
        return makespan

class Flower:
    def __init__(self, decision_variables, lower_bound, upper_bound):
        self.position = np.random.uniform(low=lower_bound, high=upper_bound, size=decision_variables)
        self.fitness = np.inf

class SimulatedAnnealing:
    def __init__(self, fitness_function, initial_solution, initial_temperature, cooling_rate):
        self.fitness_function = fitness_function
        self.current_solution = initial_solution
        self.current_fitness = self.fitness_function(self.current_solution)
        self.best_solution = self.current_solution
        self.best_fitness = self.current_fitness
        self.temperature = initial_temperature
        self.cooling_rate = cooling_rate

    def accept(self, candidate_fitness):
        if candidate_fitness < self.current_fitness:
            return True
        else:
            delta = self.current_fitness - candidate_fitness
            probability = np.exp(delta / self.temperature)
            return np.random.rand() < probability

    def cool_down(self):
        self.temperature *= self.cooling_rate

class FlowerPollination:
    def __init__(self, fitness_function, population_size=20, decision_variables=10, lower_bound=0, upper_bound=1, generations=100, switch_prob=0.8, gamma=0.1, beta=1.5):
        self.population = [Flower(decision_variables, lower_bound, upper_bound) for _ in range(population_size)]
        self.global_best = None
        self.fitness_function = fitness_function
        self.population_size = population_size
        self.decision_variables = decision_variables
        self.lower_bound = lower_bound
        self.upper_bound = upper_bound
        self.generations = generations
        self.switch_prob = switch_prob
        self.gamma = gamma
        self.beta = beta

    def levy_flight(self, beta):
        sigma = (np.math.gamma(1 + beta) * np.sin(np.pi * beta / 2) / (np.math.gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))) ** (1 / beta)
        u = np.random.normal(0, sigma, size=self.decision_variables)
        v = np.random.normal(0, 1, size=self.decision_variables)
        step = u / abs(v) ** (1 / beta)
        return step

    def global_pollination(self, flower):
        step_size = self.gamma * self.levy_flight(self.beta)
        new_position = flower.position + step_size * (flower.position - self.global_best.position)
        return new_position

    def local_pollination(self, flower):
        flower_j = np.random.choice(self.population)
        epsilon = np.random.uniform(low=0, high=1, size=self.decision_variables)
        new_position = flower.position + epsilon * (flower_j.position - flower.position)
        return new_position

    def pollination(self, flower):
        r = np.random.uniform(low=0, high=1)
        if r < self.switch_prob:
            new_position = self.global_pollination(flower)
        else:
            new_position = self.local_pollination(flower)
        return np.clip(new_position, self.lower_bound, self.upper_bound)

    def find_global_best(self):
        for flower in self.population:
            if flower.fitness < self.global_best.fitness:
                self.global_best = flower

    def optimize(self):
        self.global_best = self.population[0]
        self.global_best.fitness = self.fitness_function(self.global_best.position)
        sa = SimulatedAnnealing(self.fitness_function, self.global_best.position, initial_temperature=10, cooling_rate=0.9)

        for g in range(self.generations):
            for flower in self.population:
                flower.fitness = self.fitness_function(flower.position)
                self.find_global_best()

                new_position = self.pollination(flower)
                new_fitness = self.fitness_function(new_position)

                if sa.accept(new_fitness):
                    flower.position = new_position
                    flower.fitness = new_fitness

            sa.cool_down()  # cool down the temperature after each generation
            self.find_global_best()
            print(f"Generation: {g}, Best fitness: {self.global_best.fitness}")

        return self.global_best


class DynamicScheduler:
    def __init__(self, env, server_speeds):
        self.env = env
        self.servers = [Server(env, speed) for speed in server_speeds]

    def add_tasks(self, tasks):  # Modified method
        for task in tasks:
            self.add_task(task)

    def add_task(self, task):
        server = min(self.servers, key=lambda server: server.expected_end_time)
        self.env.process(server.process(task))

task_sizes = [200, 500, 1000]  # Your task sizes
tasks = [Task(size) for size in task_sizes]  # Create Task objects

env = simpy.Environment()
scheduler = DynamicScheduler(env, [1, 2, 3, 4, 5])  # Assuming 5 servers with speeds 1-5
scheduler.add_tasks(tasks)  # Add the tasks

env.run()

# %%
import simpy
import numpy as np

class Server:
    def __init__(self, env, speed=1):
        self.env = env
        self.machine = simpy.Resource(env, capacity=1)
        self.latest_task_end_time = 0
        self.speed = speed
        self.expected_end_time = 0

    def process(self, task):
        with self.machine.request() as req:
            yield req
            yield self.env.timeout(task.duration / self.speed)
            self.latest_task_end_time = self.env.now
            self.expected_end_time = self.env.now + task.duration / self.speed

class Task:
    def __init__(self, duration):
        self.duration = duration

class FitnessFunction:
    def __init__(self, tasks, servers):
        self.tasks = tasks
        self.servers = servers
        self.makespans = {task_duration: [] for task_duration in tasks}  # Store makespans for each task duration

    def __call__(self, solution):
        env = simpy.Environment()
        servers = [Server(env, speed=speed) for speed in self.servers]
        task_objects = []

        for task_duration, server_index in zip(self.tasks, solution):
            task = Task(task_duration)
            task_objects.append(task)  # Keep track of task objects
            server = servers[int(server_index)]
            env.process(server.process(task))

        env.run()

        # Store makespan for each task size
        for task in task_objects:
            self.makespans[task.duration].append(server.latest_task_end_time)

        makespan = max(server.latest_task_end_time for server in servers)
        return makespan

class Flower:
    def __init__(self, decision_variables, lower_bound, upper_bound):
        self.position = np.random.uniform(low=lower_bound, high=upper_bound, size=decision_variables)
        self.fitness = np.inf

class SimulatedAnnealing:
    def __init__(self, fitness_function, initial_solution, initial_temperature, cooling_rate):
        self.fitness_function = fitness_function
        self.current_solution = initial_solution
        self.current_fitness = self.fitness_function(self.current_solution)
        self.best_solution = self.current_solution
        self.best_fitness = self.current_fitness
        self.temperature = initial_temperature
        self.cooling_rate = cooling_rate

    def accept(self, candidate_fitness):
        if candidate_fitness < self.current_fitness:
            return True
        else:
            delta = self.current_fitness - candidate_fitness
            probability = np.exp(delta / self.temperature)
            return np.random.rand() < probability

    def cool_down(self):
        self.temperature *= self.cooling_rate

class FlowerPollination:
    def __init__(self, fitness_function, population_size=20, decision_variables=10, lower_bound=0, upper_bound=1, generations=100, switch_prob=0.8, gamma=0.1, beta=1.5):
        self.population = [Flower(decision_variables, lower_bound, upper_bound) for _ in range(population_size)]
        self.global_best = None
        self.fitness_function = fitness_function
        self.population_size = population_size
        self.decision_variables = decision_variables
        self.lower_bound = lower_bound
        self.upper_bound = upper_bound
        self.generations = generations
        self.switch_prob = switch_prob
        self.gamma = gamma
        self.beta = beta

    def levy_flight(self, beta):
        sigma = (np.math.gamma(1 + beta) * np.sin(np.pi * beta / 2) / (np.math.gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))) ** (1 / beta)
        u = np.random.normal(0, sigma, size=self.decision_variables)
        v = np.random.normal(0, 1, size=self.decision_variables)
        step = u / abs(v) ** (1 / beta)
        return step

    def global_pollination(self, flower):
        step_size = self.gamma * self.levy_flight(self.beta)
        new_position = flower.position + step_size * (flower.position - self.global_best.position)
        return new_position

    def local_pollination(self, flower):
        flower_j = np.random.choice(self.population)
        epsilon = np.random.uniform(low=0, high=1, size=self.decision_variables)
        new_position = flower.position + epsilon * (flower_j.position - flower.position)
        return new_position

    def pollination(self, flower):
        r = np.random.uniform(low=0, high=1)
        if r < self.switch_prob:
            new_position = self.global_pollination(flower)
        else:
            new_position = self.local_pollination(flower)
        return np.clip(new_position, self.lower_bound, self.upper_bound)

    def find_global_best(self):
        for flower in self.population:
            if flower.fitness < self.global_best.fitness:
                self.global_best = flower

    def optimize(self):
        self.global_best = self.population[0]
        self.global_best.fitness = self.fitness_function(self.global_best.position)
        sa = SimulatedAnnealing(self.fitness_function, self.global_best.position, initial_temperature=10, cooling_rate=0.9)

        for g in range(self.generations):
            for flower in self.population:
                flower.fitness = self.fitness_function(flower.position)
                self.find_global_best()

                new_position = self.pollination(flower)
                new_fitness = self.fitness_function(new_position)

                if sa.accept(new_fitness):
                    flower.position = new_position
                    flower.fitness = new_fitness

            sa.cool_down()  # cool down the temperature after each generation
            self.find_global_best()
            print(f"Generation: {g}, Best fitness: {self.global_best.fitness}")

        return self.global_best

# Optimization process
task_sizes = [200, 500, 1000]
servers = [1, 2, 3, 4, 5]

fitness_function = FitnessFunction(task_sizes, servers)
fp = FlowerPollination(fitness_function, decision_variables=len(task_sizes), lower_bound=0, upper_bound=len(servers)-1, generations=100)

best_flower = fp.optimize()

# Printing average makespan for each task size
for task_size, makespans in fitness_function.makespans.items():
    print(f"Task size: {task_size}, Average makespan: {np.mean(makespans)}")
# Out:
# Generation: 0, Best fitness: 250.0
# Generation: 1, Best fitness: 250.0
# Generation: 2, Best fitness: 250.0
# Generation: 3, Best fitness: 250.0
# Generation: 4, Best fitness: 250.0
# Generation: 5, Best fitness: 250.0
# Generation: 6, Best fitness: 250.0
# Generation: 7, Best fitness: 250.0
# Generation: 8, Best fitness: 250.0
# Generation: 9, Best fitness: 250.0
# Generation: 10, Best fitness: 250.0
# Generation: 11, Best fitness: 250.0
# Generation: 12, Best fitness: 250.0
# Generation: 13, Best fitness: 250.0
# Generation: 14, Best fitness: 250.0
# Generation: 15, Best fitness: 250.0
# Generation: 16, Best fitness: 250.0
# Generation: 17, Best fitness: 250.0
# Generation: 18, Best fitness: 250.0
# Generation: 19, Best fitness: 250.0
# Generation: 20, Best fitness: 250.0
# Generation: 21, Best fitness: 200.0
# Generation: 22, Best fitness: 200.0
# Generation: 23, Best fitness: 200.0
# Generation: 24, Best fitness: 200.0
# Generation: 25, Best fitness: 200.0
# Generation: 26, Best fitness: 200.0
# Generation: 27, Best fitness: 200.0
# Generation: 28, Best fitness: 200.0
# Generation: 29, Best fitness: 200.0
# Generation: 30, Best fitness: 200.0
# Generation: 31, Best fitness: 200.0
# Generation: 32, Best fitness: 200.0
# Generation: 33, Best fitness: 200.0
# Generation: 34, Best fitness: 200.0
# Generation: 35, Best fitness: 200.0
# Generation: 36, Best fitness: 200.0
# Generation: 37, Best fitness: 200.0
# Generation: 38, Best fitness: 250.0
# Generation: 39, Best fitness: 250.0
# Generation: 40, Best fitness: 250.0
# Generation: 41, Best fitness: 250.0
# Generation: 42, Best fitness: 250.0
# Generation: 43, Best fitness: 250.0
# Generation: 44, Best fitness: 250.0
# Generation: 45, Best fitness: 250.0
# Generation: 46, Best fitness: 250.0
# Generation: 47, Best fitness: 250.0
# Generation: 48, Best fitness: 250.0
# Generation: 49, Best fitness: 250.0
# Generation: 50, Best fitness: 250.0
# Generation: 51, Best fitness: 250.0
# Generation: 52, Best fitness: 250.0
# Generation: 53, Best fitness: 250.0
# Generation: 54, Best fitness: 250.0
# Generation: 55, Best fitness: 333.3333333333333
# Generation: 56, Best fitness: 350.0
# Generation: 57, Best fitness: 350.0
# Generation: 58, Best fitness: 350.0
# Generation: 59, Best fitness: 333.3333333333333
# Generation: 60, Best fitness: 333.3333333333333
# Generation: 61, Best fitness: 333.3333333333333
# Generation: 62, Best fitness: 333.3333333333333
# Generation: 63, Best fitness: 300.0
# Generation: 64, Best fitness: 300.0
# Generation: 65, Best fitness: 300.0
# Generation: 66, Best fitness: 300.0
# Generation: 67, Best fitness: 300.0
# Generation: 68, Best fitness: 300.0
# Generation: 69, Best fitness: 300.0
# Generation: 70, Best fitness: 333.3333333333333
# Generation: 71, Best fitness: 333.3333333333333
# Generation: 72, Best fitness: 333.3333333333333
# Generation: 73, Best fitness: 333.3333333333333
# Generation: 74, Best fitness: 250.0
# Generation: 75, Best fitness: 250.0
# Generation: 76, Best fitness: 250.0
# Generation: 77, Best fitness: 250.0
# Generation: 78, Best fitness: 250.0
# Generation: 79, Best fitness: 250.0
# Generation: 80, Best fitness: 250.0
# Generation: 81, Best fitness: 250.0
# Generation: 82, Best fitness: 250.0
# Generation: 83, Best fitness: 333.3333333333333
# Generation: 84, Best fitness: 333.3333333333333
# Generation: 85, Best fitness: 333.3333333333333
# Generation: 86, Best fitness: 333.3333333333333
# Generation: 87, Best fitness: 333.3333333333333
# Generation: 88, Best fitness: 333.3333333333333
# Generation: 89, Best fitness: 333.3333333333333
# Generation: 90, Best fitness: 333.3333333333333
# Generation: 91, Best fitness: 333.3333333333333
# Generation: 92, Best fitness: 333.3333333333333
# Generation: 93, Best fitness: 333.3333333333333
# Generation: 94, Best fitness: 333.3333333333333
# Generation: 95, Best fitness: 333.3333333333333
# Generation: 96, Best fitness: 333.3333333333333
# Generation: 97, Best fitness: 333.3333333333333
# Generation: 98, Best fitness: 333.3333333333333
# Generation: 99, Best fitness: 333.3333333333333
# Task size: 200, Average makespan: 425.2394636015325
# Task size: 500, Average makespan: 425.2394636015325
# Task size: 1000, Average makespan: 425.2394636015325

# %%
import simpy
import numpy as np

class Server:
    def __init__(self, env, speed=1):
        self.env = env
        self.machine = simpy.Resource(env, capacity=1)
        self.latest_task_end_time = 0
        self.speed = speed
        self.expected_end_time = 0

    def process(self, task):
        with self.machine.request() as req:
            yield req
            yield self.env.timeout(task.duration / self.speed)
            self.latest_task_end_time = self.env.now
            self.expected_end_time = self.env.now + task.duration / self.speed

class Task:
    def __init__(self, duration):
        self.duration = duration

class FitnessFunction:
    def __init__(self, tasks, servers):
        self.tasks = tasks
        self.servers = servers
        self.makespans = {task_duration: [] for task_duration in tasks}  # Store makespans for each task duration

    def __call__(self, solution):
        env = simpy.Environment()
        servers = [Server(env, speed=speed) for speed in self.servers]
        task_objects = []

        for task_duration, server_index in zip(self.tasks, solution):
            task = Task(task_duration)
            task_objects.append(task)  # Keep track of task objects
            server = servers[int(server_index)]
            env.process(server.process(task))

        env.run()

        # Store makespan for each task size
        for task in task_objects:
            self.makespans[task.duration].append(server.latest_task_end_time)

        makespan = max(server.latest_task_end_time for server in servers)
        return makespan

class Flower:
    def __init__(self, decision_variables, lower_bound, upper_bound):
        self.position = np.random.uniform(low=lower_bound, high=upper_bound, size=decision_variables)
        self.fitness = np.inf

class SimulatedAnnealing:
    def __init__(self, fitness_function, initial_solution, initial_temperature, cooling_rate):
        self.fitness_function = fitness_function
        self.current_solution = initial_solution
        self.current_fitness = self.fitness_function(self.current_solution)
        self.best_solution = self.current_solution
        self.best_fitness = self.current_fitness
        self.temperature = initial_temperature
        self.cooling_rate = cooling_rate

    def accept(self, candidate_fitness):
        if candidate_fitness < self.current_fitness:
            return True
        else:
            delta = self.current_fitness - candidate_fitness
            probability = np.exp(delta / self.temperature)
            return np.random.rand() < probability

    def cool_down(self):
        self.temperature *= self.cooling_rate

class FlowerPollination:
    def __init__(self, fitness_function, population_size=20, decision_variables=10, lower_bound=0, upper_bound=1, generations=100, switch_prob=0.8, gamma=0.1, beta=1.5):
        self.population = [Flower(decision_variables, lower_bound, upper_bound) for _ in range(population_size)]
        self.global_best = None
        self.fitness_function = fitness_function
        self.population_size = population_size
        self.decision_variables = decision_variables
        self.lower_bound = lower_bound
        self.upper_bound = upper_bound
        self.generations = generations
        self.switch_prob = switch_prob
        self.gamma = gamma
        self.beta = beta

    def levy_flight(self, beta):
        sigma = (np.math.gamma(1 + beta) * np.sin(np.pi * beta / 2) / (np.math.gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))) ** (1 / beta)
        u = np.random.normal(0, sigma, size=self.decision_variables)
        v = np.random.normal(0, 1, size=self.decision_variables)
        step = u / abs(v) ** (1 / beta)
        return step

    def global_pollination(self, flower):
        step_size = self.gamma * self.levy_flight(self.beta)
        new_position = flower.position + step_size * (flower.position - self.global_best.position)
        return new_position

    def local_pollination(self, flower):
        flower_j = np.random.choice(self.population)
        epsilon = np.random.uniform(low=0, high=1, size=self.decision_variables)
        new_position = flower.position + epsilon * (flower_j.position - flower.position)
        return new_position

    def pollination(self, flower):
        r = np.random.uniform(low=0, high=1)
        if r < self.switch_prob:
            new_position = self.global_pollination(flower)
        else:
            new_position = self.local_pollination(flower)
        return np.clip(new_position, self.lower_bound, self.upper_bound)

    def find_global_best(self):
        for flower in self.population:
            if flower.fitness < self.global_best.fitness:
                self.global_best = flower

    def optimize(self):
        self.global_best = self.population[0]
        self.global_best.fitness = self.fitness_function(self.global_best.position)
        sa = SimulatedAnnealing(self.fitness_function, self.global_best.position, initial_temperature=10, cooling_rate=0.9)

        for g in range(self.generations):
            for flower in self.population:
                flower.fitness = self.fitness_function(flower.position)
                self.find_global_best()

                new_position = self.pollination(flower)
                new_fitness = self.fitness_function(new_position)

                if sa.accept(new_fitness):
                    flower.position = new_position
                    flower.fitness = new_fitness

            sa.cool_down()  # cool down the temperature after each generation
            self.find_global_best()
            print(f"Generation: {g}, Best fitness: {self.global_best.fitness}")

        return self.global_best

# Optimization process
servers = [1, 2, 3, 4, 5]
task_sizes = [200, 500, 1000]

for task_size in task_sizes:
    print(f"Optimizing for task size: {task_size}")
    fitness_function = FitnessFunction([task_size], servers)  # Single task size
    fp = FlowerPollination(fitness_function, decision_variables=1, lower_bound=0, upper_bound=len(servers)-1, generations=100)
    best_flower = fp.optimize()
    print(f"Average makespan for task size {task_size}: {np.mean(fitness_function.makespans[task_size])}")
# Out:
# Optimizing for task size: 200
# Generation: 0, Best fitness: 40.0
# Generation: 1, Best fitness: 40.0
# Generation: 2, Best fitness: 40.0
# Generation: 3, Best fitness: 40.0
# Generation: 4, Best fitness: 40.0
# Generation: 5, Best fitness: 40.0
# Generation: 6, Best fitness: 40.0
# Generation: 7, Best fitness: 40.0
# Generation: 8, Best fitness: 40.0
# Generation: 9, Best fitness: 40.0
# Generation: 10, Best fitness: 50.0
# Generation: 11, Best fitness: 40.0
# Generation: 12, Best fitness: 40.0
# Generation: 13, Best fitness: 40.0
# Generation: 14, Best fitness: 40.0
# Generation: 15, Best fitness: 40.0
# Generation: 16, Best fitness: 40.0
# Generation: 17, Best fitness: 40.0
# Generation: 18, Best fitness: 40.0
# Generation: 19, Best fitness: 40.0
# Generation: 20, Best fitness: 40.0
# Generation: 21, Best fitness: 40.0
# Generation: 22, Best fitness: 40.0
# Generation: 23, Best fitness: 40.0
# Generation: 24, Best fitness: 40.0
# Generation: 25, Best fitness: 40.0
# Generation: 26, Best fitness: 40.0
# Generation: 27, Best fitness: 40.0
# Generation: 28, Best fitness: 40.0
# Generation: 29, Best fitness: 50.0
# Generation: 30, Best fitness: 50.0
# Generation: 31, Best fitness: 40.0
# Generation: 32, Best fitness: 50.0
# Generation: 33, Best fitness: 50.0
# Generation: 34, Best fitness: 50.0
# Generation: 35, Best fitness: 50.0
# Generation: 36, Best fitness: 50.0
# Generation: 37, Best fitness: 50.0
# Generation: 38, Best fitness: 50.0
# Generation: 39, Best fitness: 50.0
# Generation: 40, Best fitness: 50.0
# Generation: 41, Best fitness: 50.0
# Generation: 42, Best fitness: 50.0
# Generation: 43, Best fitness: 50.0
# Generation: 44, Best fitness: 50.0
# Generation: 45, Best fitness: 50.0
# Generation: 46, Best fitness: 50.0
# Generation: 47, Best fitness: 50.0
# Generation: 48, Best fitness: 50.0
# Generation: 49, Best fitness: 50.0
# Generation: 50, Best fitness: 50.0
# Generation: 51, Best fitness: 50.0
# Generation: 52, Best fitness: 50.0
# Generation: 53, Best fitness: 50.0
# Generation: 54, Best fitness: 50.0
# Generation: 55, Best fitness: 50.0
# Generation: 56, Best fitness: 50.0
# Generation: 57, Best fitness: 50.0
# Generation: 58, Best fitness: 50.0
# Generation: 59, Best fitness: 50.0
# Generation: 60, Best fitness: 50.0
# Generation: 61, Best fitness: 50.0
# Generation: 62, Best fitness: 50.0
# Generation: 63, Best fitness: 50.0
# Generation: 64, Best fitness: 50.0
# Generation: 65, Best fitness: 50.0
# Generation: 66, Best fitness: 50.0
# Generation: 67, Best fitness: 50.0
# Generation: 68, Best fitness: 40.0
# Generation: 69, Best fitness: 40.0
# Generation: 70, Best fitness: 40.0
# Generation: 71, Best fitness: 40.0
# Generation: 72, Best fitness: 40.0
# Generation: 73, Best fitness: 50.0
# Generation: 74, Best fitness: 50.0
# Generation: 75, Best fitness: 50.0
# Generation: 76, Best fitness: 50.0
# Generation: 77, Best fitness: 50.0
# Generation: 78, Best fitness: 50.0
# Generation: 79, Best fitness: 50.0
# Generation: 80, Best fitness: 50.0
# Generation: 81, Best fitness: 50.0
# Generation: 82, Best fitness: 50.0
# Generation: 83, Best fitness: 50.0
# Generation: 84, Best fitness: 50.0
# Generation: 85, Best fitness: 50.0
# Generation: 86, Best fitness: 50.0
# Generation: 87, Best fitness: 50.0
# Generation: 88, Best fitness: 50.0
# Generation: 89, Best fitness: 50.0
# Generation: 90, Best fitness: 50.0
# Generation: 91, Best fitness: 50.0
# Generation: 92, Best fitness: 50.0
# Generation: 93, Best fitness: 50.0
# Generation: 94, Best fitness: 50.0
# Generation: 95, Best fitness: 50.0
# Generation: 96, Best fitness: 50.0
# Generation: 97, Best fitness: 50.0
# Generation: 98, Best fitness: 50.0
# Generation: 99, Best fitness: 50.0
# Average makespan for task size 200: 64.28868898883891
# Optimizing for task size: 500
# Generation: 0, Best fitness: 125.0
# Generation: 1, Best fitness: 125.0
# Generation: 2, Best fitness: 125.0
# Generation: 3, Best fitness: 125.0
# Generation: 4, Best fitness: 125.0
# Generation: 5, Best fitness: 125.0
# Generation: 6, Best fitness: 125.0
# Generation: 7, Best fitness: 125.0
# Generation: 8, Best fitness: 125.0
# Generation: 9, Best fitness: 125.0
# Generation: 10, Best fitness: 100.0
# Generation: 11, Best fitness: 100.0
# Generation: 12, Best fitness: 100.0
# Generation: 13, Best fitness: 100.0
# Generation: 14, Best fitness: 100.0
# Generation: 15, Best fitness: 100.0
# Generation: 16, Best fitness: 100.0
# Generation: 17, Best fitness: 100.0
# Generation: 18, Best fitness: 100.0
# Generation: 19, Best fitness: 100.0
# Generation: 20, Best fitness: 100.0
# Generation: 21, Best fitness: 100.0
# Generation: 22, Best fitness: 125.0
# Generation: 23, Best fitness: 125.0
# Generation: 24, Best fitness: 125.0
# Generation: 25, Best fitness: 100.0
# Generation: 26, Best fitness: 100.0
# Generation: 27, Best fitness: 100.0
# Generation: 28, Best fitness: 100.0
# Generation: 29, Best fitness: 100.0
# Generation: 30, Best fitness: 100.0
# Generation: 31, Best fitness: 100.0
# Generation: 32, Best fitness: 100.0
# Generation: 33, Best fitness: 100.0
# Generation: 34, Best fitness: 100.0
# Generation: 35, Best fitness: 100.0
# Generation: 36, Best fitness: 100.0
# Generation: 37, Best fitness: 100.0
# Generation: 38, Best fitness: 100.0
# Generation: 39, Best fitness: 100.0
# Generation: 40, Best fitness: 125.0
# Generation: 41, Best fitness: 125.0
# Generation: 42, Best fitness: 125.0
# Generation: 43, Best fitness: 125.0
# Generation: 44, Best fitness: 125.0
# Generation: 45, Best fitness: 125.0
# Generation: 46, Best fitness: 125.0
# Generation: 47, Best fitness: 125.0
# Generation: 48, Best fitness: 125.0
# Generation: 49, Best fitness: 125.0
# Generation: 50, Best fitness: 125.0
# Generation: 51, Best fitness: 125.0
# Generation: 52, Best fitness: 125.0
# Generation: 53, Best fitness: 125.0
# Generation: 54, Best fitness: 125.0
# Generation: 55, Best fitness: 125.0
# Generation: 56, Best fitness: 125.0
# Generation: 57, Best fitness: 125.0
# Generation: 58, Best fitness: 125.0
# Generation: 59, Best fitness: 125.0
# Generation: 60, Best fitness: 125.0
# Generation: 61, Best fitness: 125.0
# Generation: 62, Best fitness: 125.0
# Generation: 63, Best fitness: 125.0
# Generation: 64, Best fitness: 125.0
# Generation: 65, Best fitness: 125.0
# Generation: 66, Best fitness: 125.0
# Generation: 67, Best fitness: 125.0
# Generation: 68, Best fitness: 125.0
# Generation: 69, Best fitness: 125.0
# Generation: 70, Best fitness: 125.0
# Generation: 71, Best fitness: 125.0
# Generation: 72, Best fitness: 125.0
# Generation: 73, Best fitness: 125.0
# Generation: 74, Best fitness: 125.0
# Generation: 75, Best fitness: 125.0
# Generation: 76, Best fitness: 125.0
# Generation: 77, Best fitness: 125.0
# Generation: 78, Best fitness: 100.0
# Generation: 79, Best fitness: 100.0
# Generation: 80, Best fitness: 100.0
# Generation: 81, Best fitness: 100.0
# Generation: 82, Best fitness: 100.0
# Generation: 83, Best fitness: 100.0
# Generation: 84, Best fitness: 100.0
# Generation: 85, Best fitness: 100.0
# Generation: 86, Best fitness: 100.0
# Generation: 87, Best fitness: 100.0
# Generation: 88, Best fitness: 100.0
# Generation: 89, Best fitness: 100.0
# Generation: 90, Best fitness: 100.0
# Generation: 91, Best fitness: 100.0
# Generation: 92, Best fitness: 100.0
# Generation: 93, Best fitness: 100.0
# Generation: 94, Best fitness: 100.0
# Generation: 95, Best fitness: 100.0
# Generation: 96, Best fitness: 100.0
# Generation: 97, Best fitness: 125.0
# Generation: 98, Best fitness: 125.0
# Generation: 99, Best fitness: 125.0
# Average makespan for task size 500: 146.91404297851074
# Optimizing for task size: 1000
# Generation: 0, Best fitness: 250.0
# Generation: 1, Best fitness: 250.0
# Generation: 2, Best fitness: 250.0
# Generation: 3, Best fitness: 250.0
# Generation: 4, Best fitness: 250.0
# Generation: 5, Best fitness: 250.0
# Generation: 6, Best fitness: 250.0
# Generation: 7, Best fitness: 250.0
# Generation: 8, Best fitness: 250.0
# Generation: 9, Best fitness: 200.0
# Generation: 10, Best fitness: 250.0
# Generation: 11, Best fitness: 250.0
# Generation: 12, Best fitness: 250.0
# Generation: 13, Best fitness: 250.0
# Generation: 14, Best fitness: 250.0
# Generation: 15, Best fitness: 250.0
# Generation: 16, Best fitness: 250.0
# Generation: 17, Best fitness: 333.3333333333333
# Generation: 18, Best fitness: 333.3333333333333
# Generation: 19, Best fitness: 333.3333333333333
# Generation: 20, Best fitness: 250.0
# Generation: 21, Best fitness: 333.3333333333333
# Generation: 22, Best fitness: 333.3333333333333
# Generation: 23, Best fitness: 333.3333333333333
# Generation: 24, Best fitness: 333.3333333333333
# Generation: 25, Best fitness: 333.3333333333333
# Generation: 26, Best fitness: 333.3333333333333
# Generation: 27, Best fitness: 333.3333333333333
# Generation: 28, Best fitness: 333.3333333333333
# Generation: 29, Best fitness: 333.3333333333333
# Generation: 30, Best fitness: 333.3333333333333
# Generation: 31, Best fitness: 333.3333333333333
# Generation: 32, Best fitness: 333.3333333333333
# Generation: 33, Best fitness: 333.3333333333333
# Generation: 34, Best fitness: 333.3333333333333
# Generation: 35, Best fitness: 333.3333333333333
# Generation: 36, Best fitness: 333.3333333333333
# Generation: 37, Best fitness: 200.0
# Generation: 38, Best fitness: 200.0
# Generation: 39, Best fitness: 200.0
# Generation: 40, Best fitness: 200.0
# Generation: 41, Best fitness: 200.0
# Generation: 42, Best fitness: 200.0
# Generation: 43, Best fitness: 333.3333333333333
# Generation: 44, Best fitness: 333.3333333333333
# Generation: 45, Best fitness: 333.3333333333333
# Generation: 46, Best fitness: 333.3333333333333
# Generation: 47, Best fitness: 250.0
# Generation: 48, Best fitness: 333.3333333333333
# Generation: 49, Best fitness: 333.3333333333333
# Generation: 50, Best fitness: 333.3333333333333
# Generation: 51, Best fitness: 333.3333333333333
# Generation: 52, Best fitness: 333.3333333333333
# Generation: 53, Best fitness: 333.3333333333333
# Generation: 54, Best fitness: 333.3333333333333
# Generation: 55, Best fitness: 333.3333333333333
# Generation: 56, Best fitness: 250.0
# Generation: 57, Best fitness: 250.0
# Generation: 58, Best fitness: 250.0
# Generation: 59, Best fitness: 333.3333333333333
# Generation: 60, Best fitness: 333.3333333333333
# Generation: 61, Best fitness: 333.3333333333333
# Generation: 62, Best fitness: 333.3333333333333
# Generation: 63, Best fitness: 333.3333333333333
# Generation: 64, Best fitness: 333.3333333333333
# Generation: 65, Best fitness: 333.3333333333333
# Generation: 66, Best fitness: 333.3333333333333
# Generation: 67, Best fitness: 333.3333333333333
# Generation: 68, Best fitness: 250.0
# Generation: 69, Best fitness: 200.0
# Generation: 70, Best fitness: 200.0
# Generation: 71, Best fitness: 200.0
# Generation: 72, Best fitness: 200.0
# Generation: 73, Best fitness: 200.0
# Generation: 74, Best fitness: 200.0
# Generation: 75, Best fitness: 200.0
# Generation: 76, Best fitness: 250.0
# Generation: 77, Best fitness: 250.0
# Generation: 78, Best fitness: 250.0
# Generation: 79, Best fitness: 200.0
# Generation: 80, Best fitness: 250.0
# Generation: 81, Best fitness: 250.0
# Generation: 82, Best fitness: 250.0
# Generation: 83, Best fitness: 333.3333333333333
# Generation: 84, Best fitness: 333.3333333333333
# Generation: 85, Best fitness: 333.3333333333333
# Generation: 86, Best fitness: 333.3333333333333
# Generation: 87, Best fitness: 333.3333333333333
# Generation: 88, Best fitness: 333.3333333333333
# Generation: 89, Best fitness: 333.3333333333333
# Generation: 90, Best fitness: 333.3333333333333
# Generation: 91, Best fitness: 333.3333333333333
# Generation: 92, Best fitness: 333.3333333333333
# Generation: 93, Best fitness: 333.3333333333333
# Generation: 94, Best fitness: 333.3333333333333
# Generation: 95, Best fitness: 333.3333333333333
# Generation: 96, Best fitness: 333.3333333333333
# Generation: 97, Best fitness: 333.3333333333333
# Generation: 98, Best fitness: 333.3333333333333
# Generation: 99, Best fitness: 333.3333333333333
# Average makespan for task size 1000: 562.6145260702982

# %%
import simpy
import numpy as np


class Server:
    def __init__(self, env, speed=1):
        self.env = env
        self.machine = simpy.Resource(env, capacity=1)
        self.latest_task_end_time = 0
        self.speed = speed
        self.expected_end_time = 0

    def process(self, task):
        with self.machine.request() as req:
            yield req
            yield self.env.timeout(task.duration / self.speed)
            self.latest_task_end_time = self.env.now
            self.expected_end_time = self.env.now + task.duration / self.speed


class Task:
    def __init__(self, duration):
        self.duration = duration


class FitnessFunction:
    def __init__(self, tasks, servers):
        self.tasks = tasks
        self.servers = servers
        # Store makespans for each task duration
        self.makespans = {task_duration: [] for task_duration in tasks}

    def __call__(self, solution):
        env = simpy.Environment()
        servers = [Server(env, speed=speed) for speed in self.servers]
        task_objects = []

        for task_duration, server_index in zip(self.tasks, solution):
            task = Task(task_duration)
            task_objects.append(task)  # Keep track of task objects
            server = servers[int(server_index)]
            env.process(server.process(task))

        env.run()

        # Store makespan for each task size
        for task in task_objects:
            self.makespans[task.duration].append(server.latest_task_end_time)

        makespan = max(server.latest_task_end_time for server in servers)
        return makespan


class Flower:
    def __init__(self, decision_variables, lower_bound, upper_bound):
        self.position = np.random.uniform(
            low=lower_bound, high=upper_bound, size=decision_variables)
        self.fitness = np.inf


class SimulatedAnnealing:
    def __init__(self, fitness_function, initial_solution, initial_temperature, final_temperature, cooling_rate):
        self.fitness_function = fitness_function
        self.current_solution = initial_solution
        self.current_fitness = self.fitness_function(self.current_solution)
        self.best_solution = self.current_solution
        self.best_fitness = self.current_fitness
        self.temperature = initial_temperature
        self.final_temperature = final_temperature
        self.cooling_rate = cooling_rate

    def accept(self, candidate_fitness):
        if candidate_fitness < self.current_fitness:
            return True
        else:
            delta = self.current_fitness - candidate_fitness
            probability = np.exp(delta / self.temperature)
            return np.random.rand() < probability

    def cool_down(self):
        if self.temperature > self.final_temperature:
            self.temperature *= self.cooling_rate


class FlowerPollination:
    def __init__(self, fitness_function, population_size=100, decision_variables=10, lower_bound=0, upper_bound=1, generations=1000, switch_prob=0.8, gamma=0.1, beta=1.5):
        self.population = [Flower(
            decision_variables, lower_bound, upper_bound) for _ in range(population_size)]
        self.global_best = None
        self.fitness_function = fitness_function
        self.population_size = population_size
        self.decision_variables = decision_variables
        self.lower_bound = lower_bound
        self.upper_bound = upper_bound
        self.generations = generations
        self.switch_prob = switch_prob
        self.gamma = gamma
        self.beta = beta

    def levy_flight(self, beta):
        sigma = (np.math.gamma(1 + beta) * np.sin(np.pi * beta / 2) /
                 (np.math.gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))) ** (1 / beta)
        u = np.random.normal(0, sigma, size=self.decision_variables)
        v = np.random.normal(0, 1, size=self.decision_variables)
        step = u / abs(v) ** (1 / beta)
        return step

    def global_pollination(self, flower):
        step_size = self.gamma * self.levy_flight(self.beta)
        new_position = flower.position + step_size * \
            (flower.position - self.global_best.position)
        return new_position

    def local_pollination(self, flower):
        flower_j = np.random.choice(self.population)
        epsilon = np.random.uniform(
            low=0, high=1, size=self.decision_variables)
        new_position = flower.position + epsilon * \
            (flower_j.position - flower.position)
        return new_position

    def pollination(self, flower):
        r = np.random.uniform(low=0, high=1)
        if r < self.switch_prob:
            new_position = self.global_pollination(flower)
        else:
            new_position = self.local_pollination(flower)
        return np.clip(new_position, self.lower_bound, self.upper_bound)

    def find_global_best(self):
        for flower in self.population:
            if flower.fitness < self.global_best.fitness:
                self.global_best = flower


    def optimize(self):
        self.global_best = self.population[0]
        self.global_best.fitness = self.fitness_function(self.global_best.position)
        sa = SimulatedAnnealing(self.fitness_function, self.global_best.position, initial_temperature=10, final_temperature=0.001, cooling_rate=0.9)

        for g in range(self.generations):
            for flower in self.population:
                flower.fitness = self.fitness_function(flower.position)
                self.find_global_best()

                new_position = self.pollination(flower)
                new_fitness = self.fitness_function(new_position)

                if sa.accept(new_fitness):
                    flower.position = new_position
                    flower.fitness = new_fitness

            sa.cool_down()  # cool down the temperature after each generation
            self.find_global_best()
            print(f"Generation: {g}, Best fitness: {self.global_best.fitness}")

        return self.global_best



# Optimization process
servers = [1, 2, 3, 4, 5]
task_sizes = [200, 500, 1000]

for task_size in task_sizes:
    print(f"Optimizing for task size: {task_size}")
    fitness_function = FitnessFunction(
        [task_size], servers)  # Single task size
    fp = FlowerPollination(fitness_function, decision_variables=1,
                           lower_bound=0, upper_bound=len(servers)-1, generations=1000)
    best_flower = fp.optimize()
    print(
        f"Average makespan for task size {task_size}: {np.mean(fitness_function.makespans[task_size])}")
# Out:
# Optimizing for task size: 200
# Generation: 0, Best fitness: 50.0
# Generation: 1, Best fitness: 50.0
# Generation: 2, Best fitness: 50.0
# Generation: 3, Best fitness: 50.0
# Generation: 4, Best fitness: 40.0
# Generation: 5, Best fitness: 40.0
# Generation: 6, Best fitness: 40.0
# Generation: 7, Best fitness: 40.0
# Generation: 8, Best fitness: 40.0
# Generation: 9, Best fitness: 40.0
# Generation: 10, Best fitness: 40.0
# Generation: 11, Best fitness: 40.0
# Generation: 12, Best fitness: 40.0
# Generation: 13, Best fitness: 40.0
# Generation: 14, Best fitness: 40.0
# Generation: 15, Best fitness: 40.0
# Generation: 16, Best fitness: 40.0
# Generation: 17, Best fitness: 40.0
# Generation: 18, Best fitness: 40.0
# Generation: 19, Best fitness: 40.0
# Generation: 20, Best fitness: 40.0
# Generation: 21, Best fitness: 40.0
# Generation: 22, Best fitness: 40.0
# Generation: 23, Best fitness: 40.0
# Generation: 24, Best fitness: 40.0
# Generation: 25, Best fitness: 40.0
# Generation: 26, Best fitness: 40.0
# Generation: 27, Best fitness: 40.0
# Generation: 28, Best fitness: 40.0
# Generation: 29, Best fitness: 40.0
# Generation: 30, Best fitness: 40.0
# Generation: 31, Best fitness: 40.0
# Generation: 32, Best fitness: 40.0
# Generation: 33, Best fitness: 40.0
# Generation: 34, Best fitness: 40.0
# Generation: 35, Best fitness: 40.0
# Generation: 36, Best fitness: 40.0
# Generation: 37, Best fitness: 40.0
# Generation: 38, Best fitness: 40.0
# Generation: 39, Best fitness: 40.0
# Generation: 40, Best fitness: 40.0
# Generation: 41, Best fitness: 40.0
# Generation: 42, Best fitness: 40.0
# Generation: 43, Best fitness: 40.0
# Generation: 44, Best fitness: 40.0
# Generation: 45, Best fitness: 40.0
# Generation: 46, Best fitness: 40.0
# Generation: 47, Best fitness: 40.0
# Generation: 48, Best fitness: 40.0
# Generation: 49, Best fitness: 40.0
# Generation: 50, Best fitness: 40.0
# Generation: 51, Best fitness: 40.0
# Generation: 52, Best fitness: 40.0
# Generation: 53, Best fitness: 40.0
# Generation: 54, Best fitness: 40.0
# Generation: 55, Best fitness: 40.0
# Generation: 56, Best fitness: 40.0
# Generation: 57, Best fitness: 40.0
# Generation: 58, Best fitness: 50.0
# Generation: 59, Best fitness: 50.0
# Generation: 60, Best fitness: 40.0
# Generation: 61, Best fitness: 40.0
# Generation: 62, Best fitness: 40.0
# Generation: 63, Best fitness: 40.0
# Generation: 64, Best fitness: 40.0
# Generation: 65, Best fitness: 40.0
# Generation: 66, Best fitness: 40.0
# Generation: 67, Best fitness: 40.0
# Generation: 68, Best fitness: 40.0
# Generation: 69, Best fitness: 40.0
# Generation: 70, Best fitness: 40.0
# Generation: 71, Best fitness: 40.0
# Generation: 72, Best fitness: 40.0
# Generation: 73, Best fitness: 40.0
# Generation: 74, Best fitness: 40.0
# Generation: 75, Best fitness: 40.0
# Generation: 76, Best fitness: 40.0
# Generation: 77, Best fitness: 40.0
# Generation: 78, Best fitness: 40.0
# Generation: 79, Best fitness: 40.0
# Generation: 80, Best fitness: 40.0
# Generation: 81, Best fitness: 40.0
# Generation: 82, Best fitness: 40.0
# Generation: 83, Best fitness: 40.0
# Generation: 84, Best fitness: 40.0
# Generation: 85, Best fitness: 40.0
# Generation: 86, Best fitness: 40.0
# Generation: 87, Best fitness: 40.0
# Generation: 88, Best fitness: 40.0
# Generation: 89, Best fitness: 40.0
# Generation: 90, Best fitness: 40.0
# Generation: 91, Best fitness: 40.0
# Generation: 92, Best fitness: 40.0
# Generation: 93, Best fitness: 40.0
# Generation: 94, Best fitness: 40.0
# Generation: 95, Best fitness: 40.0
# Generation: 96, Best fitness: 40.0
# Generation: 97, Best fitness: 40.0
# Generation: 98, Best fitness: 40.0
# Generation: 99, Best fitness: 40.0
# Generation: 100, Best fitness: 40.0
# Generation: 101, Best fitness: 40.0
# Generation: 102, Best fitness: 40.0
# Generation: 103, Best fitness: 40.0
# Generation: 104, Best fitness: 40.0
# Generation: 105, Best fitness: 40.0
# Generation: 106, Best fitness: 40.0
# Generation: 107, Best fitness: 40.0
# Generation: 108, Best fitness: 40.0
# Generation: 109, Best fitness: 40.0
# Generation: 110, Best fitness: 40.0
# Generation: 111, Best fitness: 40.0
# Generation: 112, Best fitness: 40.0
# Generation: 113, Best fitness: 40.0
# Generation: 114, Best fitness: 40.0
# Generation: 115, Best fitness: 40.0
# Generation: 116, Best fitness: 40.0
# Generation: 117, Best fitness: 40.0
# Generation: 118, Best fitness: 40.0
# Generation: 119, Best fitness: 40.0
# Generation: 120, Best fitness: 40.0
# Generation: 121, Best fitness: 40.0
# Generation: 122, Best fitness: 40.0
# Generation: 123, Best fitness: 40.0
# Generation: 124, Best fitness: 40.0
# Generation: 125, Best fitness: 40.0
# Generation: 126, Best fitness: 50.0
# Generation: 127, Best fitness: 40.0
# Generation: 128, Best fitness: 40.0
# Generation: 129, Best fitness: 40.0
# Generation: 130, Best fitness: 40.0
# Generation: 131, Best fitness: 40.0
# Generation: 132, Best fitness: 40.0
# Generation: 133, Best fitness: 40.0
# Generation: 134, Best fitness: 40.0
# Generation: 135, Best fitness: 40.0
# Generation: 136, Best fitness: 40.0
# Generation: 137, Best fitness: 40.0
# Generation: 138, Best fitness: 40.0
# Generation: 139, Best fitness: 40.0
# Generation: 140, Best fitness: 40.0
# Generation: 141, Best fitness: 40.0
# Generation: 142, Best fitness: 40.0
# Generation: 143, Best fitness: 40.0
# Generation: 144, Best fitness: 40.0
# Generation: 145, Best fitness: 40.0
# Generation: 146, Best fitness: 40.0
# Generation: 147, Best fitness: 40.0
# Generation: 148, Best fitness: 40.0
# Generation: 149, Best fitness: 40.0
# Generation: 150, Best fitness: 40.0
# Generation: 151, Best fitness: 50.0
# Generation: 152, Best fitness: 50.0
# Generation: 153, Best fitness: 50.0
# Generation: 154, Best fitness: 40.0
# Generation: 155, Best fitness: 40.0
# Generation: 156, Best fitness: 40.0
# Generation: 157, Best fitness: 50.0
# Generation: 158, Best fitness: 50.0
# Generation: 159, Best fitness: 50.0
# Generation: 160, Best fitness: 50.0
# Generation: 161, Best fitness: 50.0
# Generation: 162, Best fitness: 50.0
# Generation: 163, Best fitness: 40.0
# Generation: 164, Best fitness: 40.0
# Generation: 165, Best fitness: 40.0
# Generation: 166, Best fitness: 40.0
# Generation: 167, Best fitness: 40.0
# Generation: 168, Best fitness: 40.0
# Generation: 169, Best fitness: 40.0
# Generation: 170, Best fitness: 40.0
# Generation: 171, Best fitness: 40.0
# Generation: 172, Best fitness: 40.0
# Generation: 173, Best fitness: 40.0
# Generation: 174, Best fitness: 40.0
# Generation: 175, Best fitness: 40.0
# Generation: 176, Best fitness: 40.0
# Generation: 177, Best fitness: 40.0
# Generation: 178, Best fitness: 40.0
# Generation: 179, Best fitness: 40.0
# Generation: 180, Best fitness: 40.0
# Generation: 181, Best fitness: 40.0
# Generation: 182, Best fitness: 40.0
# Generation: 183, Best fitness: 40.0
# Generation: 184, Best fitness: 40.0
# Generation: 185, Best fitness: 40.0
# Generation: 186, Best fitness: 40.0
# Generation: 187, Best fitness: 40.0
# Generation: 188, Best fitness: 40.0
# Generation: 189, Best fitness: 40.0
# Generation: 190, Best fitness: 40.0
# Generation: 191, Best fitness: 40.0
# Generation: 192, Best fitness: 40.0
# Generation: 193, Best fitness: 40.0
# Generation: 194, Best fitness: 40.0
# Generation: 195, Best fitness: 40.0
# Generation: 196, Best fitness: 40.0
# Generation: 197, Best fitness: 50.0
# Generation: 198, Best fitness: 40.0
# Generation: 199, Best fitness: 40.0
# Generation: 200, Best fitness: 40.0
# Generation: 201, Best fitness: 40.0
# Generation: 202, Best fitness: 40.0
# Generation: 203, Best fitness: 40.0
# Generation: 204, Best fitness: 40.0
# Generation: 205, Best fitness: 40.0
# Generation: 206, Best fitness: 40.0
# Generation: 207, Best fitness: 40.0
# Generation: 208, Best fitness: 40.0
# Generation: 209, Best fitness: 40.0
# Generation: 210, Best fitness: 40.0
# Generation: 211, Best fitness: 40.0
# Generation: 212, Best fitness: 40.0
# Generation: 213, Best fitness: 40.0
# Generation: 214, Best fitness: 40.0
# Generation: 215, Best fitness: 40.0
# Generation: 216, Best fitness: 40.0
# Generation: 217, Best fitness: 40.0
# Generation: 218, Best fitness: 40.0
# Generation: 219, Best fitness: 40.0
# Generation: 220, Best fitness: 40.0
# Generation: 221, Best fitness: 40.0
# Generation: 222, Best fitness: 40.0
# Generation: 223, Best fitness: 40.0
# Generation: 224, Best fitness: 40.0
# Generation: 225, Best fitness: 50.0
# Generation: 226, Best fitness: 50.0
# Generation: 227, Best fitness: 40.0
# Generation: 228, Best fitness: 40.0
# Generation: 229, Best fitness: 40.0
# Generation: 230, Best fitness: 40.0
# Generation: 231, Best fitness: 40.0
# Generation: 232, Best fitness: 40.0
# Generation: 233, Best fitness: 40.0
# Generation: 234, Best fitness: 40.0
# Generation: 235, Best fitness: 40.0
# Generation: 236, Best fitness: 40.0
# Generation: 237, Best fitness: 40.0
# Generation: 238, Best fitness: 40.0
# Generation: 239, Best fitness: 40.0
# Generation: 240, Best fitness: 40.0
# Generation: 241, Best fitness: 40.0
# Generation: 242, Best fitness: 40.0
# Generation: 243, Best fitness: 40.0
# Generation: 244, Best fitness: 40.0
# Generation: 245, Best fitness: 40.0
# Generation: 246, Best fitness: 40.0
# Generation: 247, Best fitness: 40.0
# Generation: 248, Best fitness: 40.0
# Generation: 249, Best fitness: 40.0
# Generation: 250, Best fitness: 40.0
# Generation: 251, Best fitness: 40.0
# Generation: 252, Best fitness: 40.0
# Generation: 253, Best fitness: 40.0
# Generation: 254, Best fitness: 40.0
# Generation: 255, Best fitness: 40.0
# Generation: 256, Best fitness: 40.0
# Generation: 257, Best fitness: 40.0
# Generation: 258, Best fitness: 40.0
# Generation: 259, Best fitness: 40.0
# Generation: 260, Best fitness: 50.0
# Generation: 261, Best fitness: 50.0
# Generation: 262, Best fitness: 50.0
# Generation: 263, Best fitness: 40.0
# Generation: 264, Best fitness: 40.0
# Generation: 265, Best fitness: 50.0
# Generation: 266, Best fitness: 50.0
# Generation: 267, Best fitness: 50.0
# Generation: 268, Best fitness: 40.0
# Generation: 269, Best fitness: 50.0
# Generation: 270, Best fitness: 50.0
# Generation: 271, Best fitness: 50.0
# Generation: 272, Best fitness: 50.0
# Generation: 273, Best fitness: 50.0
# Generation: 274, Best fitness: 50.0
# Generation: 275, Best fitness: 50.0
# Generation: 276, Best fitness: 40.0
# Generation: 277, Best fitness: 40.0
# Generation: 278, Best fitness: 40.0
# Generation: 279, Best fitness: 40.0
# Generation: 280, Best fitness: 40.0
# Generation: 281, Best fitness: 40.0
# Generation: 282, Best fitness: 40.0
# Generation: 283, Best fitness: 40.0
# Generation: 284, Best fitness: 40.0
# Generation: 285, Best fitness: 40.0
# Generation: 286, Best fitness: 40.0
# Generation: 287, Best fitness: 40.0
# Generation: 288, Best fitness: 40.0
# Generation: 289, Best fitness: 40.0
# Generation: 290, Best fitness: 40.0
# Generation: 291, Best fitness: 40.0
# Generation: 292, Best fitness: 40.0
# Generation: 293, Best fitness: 40.0
# Generation: 294, Best fitness: 40.0
# Generation: 295, Best fitness: 40.0
# Generation: 296, Best fitness: 40.0
# Generation: 297, Best fitness: 40.0
# Generation: 298, Best fitness: 40.0
# Generation: 299, Best fitness: 40.0
# Generation: 300, Best fitness: 40.0
# Generation: 301, Best fitness: 40.0
# Generation: 302, Best fitness: 40.0
# Generation: 303, Best fitness: 40.0
# Generation: 304, Best fitness: 40.0
# Generation: 305, Best fitness: 40.0
# Generation: 306, Best fitness: 40.0
# Generation: 307, Best fitness: 50.0
# Generation: 308, Best fitness: 50.0
# Generation: 309, Best fitness: 50.0
# Generation: 310, Best fitness: 40.0
# Generation: 311, Best fitness: 40.0
# Generation: 312, Best fitness: 50.0
# Generation: 313, Best fitness: 50.0
# Generation: 314, Best fitness: 50.0
# Generation: 315, Best fitness: 50.0
# Generation: 316, Best fitness: 50.0
# Generation: 317, Best fitness: 40.0
# Generation: 318, Best fitness: 50.0
# Generation: 319, Best fitness: 40.0
# Generation: 320, Best fitness: 40.0
# Generation: 321, Best fitness: 50.0
# Generation: 322, Best fitness: 50.0
# Generation: 323, Best fitness: 40.0
# Generation: 324, Best fitness: 40.0
# Generation: 325, Best fitness: 40.0
# Generation: 326, Best fitness: 40.0
# Generation: 327, Best fitness: 40.0
# Generation: 328, Best fitness: 40.0
# Generation: 329, Best fitness: 50.0
# Generation: 330, Best fitness: 50.0
# Generation: 331, Best fitness: 50.0
# Generation: 332, Best fitness: 50.0
# Generation: 333, Best fitness: 50.0
# Generation: 334, Best fitness: 50.0
# Generation: 335, Best fitness: 50.0
# Generation: 336, Best fitness: 50.0
# Generation: 337, Best fitness: 50.0
# Generation: 338, Best fitness: 50.0
# Generation: 339, Best fitness: 50.0
# Generation: 340, Best fitness: 50.0
# Generation: 341, Best fitness: 40.0
# Generation: 342, Best fitness: 40.0
# Generation: 343, Best fitness: 40.0
# Generation: 344, Best fitness: 40.0
# Generation: 345, Best fitness: 40.0
# Generation: 346, Best fitness: 40.0
# Generation: 347, Best fitness: 40.0
# Generation: 348, Best fitness: 40.0
# Generation: 349, Best fitness: 40.0
# Generation: 350, Best fitness: 40.0
# Generation: 351, Best fitness: 40.0
# Generation: 352, Best fitness: 40.0
# Generation: 353, Best fitness: 40.0
# Generation: 354, Best fitness: 40.0
# Generation: 355, Best fitness: 40.0
# Generation: 356, Best fitness: 40.0
# Generation: 357, Best fitness: 40.0
# Generation: 358, Best fitness: 40.0
# Generation: 359, Best fitness: 40.0
# Generation: 360, Best fitness: 40.0
# Generation: 361, Best fitness: 40.0
# Generation: 362, Best fitness: 40.0
# Generation: 363, Best fitness: 40.0
# Generation: 364, Best fitness: 40.0
# Generation: 365, Best fitness: 40.0
# Generation: 366, Best fitness: 40.0
# Generation: 367, Best fitness: 40.0
# Generation: 368, Best fitness: 40.0
# Generation: 369, Best fitness: 40.0
# Generation: 370, Best fitness: 40.0
# Generation: 371, Best fitness: 40.0
# Generation: 372, Best fitness: 40.0
# Generation: 373, Best fitness: 40.0
# Generation: 374, Best fitness: 40.0
# Generation: 375, Best fitness: 40.0
# Generation: 376, Best fitness: 40.0
# Generation: 377, Best fitness: 40.0
# Generation: 378, Best fitness: 40.0
# Generation: 379, Best fitness: 40.0
# Generation: 380, Best fitness: 40.0
# Generation: 381, Best fitness: 40.0
# Generation: 382, Best fitness: 40.0
# Generation: 383, Best fitness: 40.0
# Generation: 384, Best fitness: 40.0
# Generation: 385, Best fitness: 40.0
# Generation: 386, Best fitness: 40.0
# Generation: 387, Best fitness: 40.0
# Generation: 388, Best fitness: 40.0
# Generation: 389, Best fitness: 40.0
# Generation: 390, Best fitness: 40.0
# Generation: 391, Best fitness: 40.0
# Generation: 392, Best fitness: 40.0
# Generation: 393, Best fitness: 40.0
# Generation: 394, Best fitness: 40.0
# Generation: 395, Best fitness: 40.0
# Generation: 396, Best fitness: 40.0
# Generation: 397, Best fitness: 40.0
# Generation: 398, Best fitness: 40.0
# Generation: 399, Best fitness: 40.0
# Generation: 400, Best fitness: 40.0
# Generation: 401, Best fitness: 40.0
# Generation: 402, Best fitness: 40.0
# Generation: 403, Best fitness: 40.0
# Generation: 404, Best fitness: 40.0
# Generation: 405, Best fitness: 40.0
# Generation: 406, Best fitness: 40.0
# Generation: 407, Best fitness: 40.0
# Generation: 408, Best fitness: 40.0
# Generation: 409, Best fitness: 40.0
# Generation: 410, Best fitness: 40.0
# Generation: 411, Best fitness: 40.0
# Generation: 412, Best fitness: 40.0
# Generation: 413, Best fitness: 40.0
# Generation: 414, Best fitness: 40.0
# Generation: 415, Best fitness: 40.0
# Generation: 416, Best fitness: 40.0
# Generation: 417, Best fitness: 50.0
# Generation: 418, Best fitness: 50.0
# Generation: 419, Best fitness: 40.0
# Generation: 420, Best fitness: 40.0
# Generation: 421, Best fitness: 40.0
# Generation: 422, Best fitness: 40.0
# Generation: 423, Best fitness: 50.0
# Generation: 424, Best fitness: 50.0
# Generation: 425, Best fitness: 40.0
# Generation: 426, Best fitness: 40.0
# Generation: 427, Best fitness: 40.0
# Generation: 428, Best fitness: 40.0
# Generation: 429, Best fitness: 40.0
# Generation: 430, Best fitness: 40.0
# Generation: 431, Best fitness: 40.0
# Generation: 432, Best fitness: 40.0
# Generation: 433, Best fitness: 40.0
# Generation: 434, Best fitness: 40.0
# Generation: 435, Best fitness: 40.0
# Generation: 436, Best fitness: 40.0
# Generation: 437, Best fitness: 40.0
# Generation: 438, Best fitness: 40.0
# Generation: 439, Best fitness: 40.0
# Generation: 440, Best fitness: 40.0
# Generation: 441, Best fitness: 50.0
# Generation: 442, Best fitness: 40.0
# Generation: 443, Best fitness: 40.0
# Generation: 444, Best fitness: 40.0
# Generation: 445, Best fitness: 40.0
# Generation: 446, Best fitness: 40.0
# Generation: 447, Best fitness: 40.0
# Generation: 448, Best fitness: 40.0
# Generation: 449, Best fitness: 40.0
# Generation: 450, Best fitness: 40.0
# Generation: 451, Best fitness: 40.0
# Generation: 452, Best fitness: 40.0
# Generation: 453, Best fitness: 40.0
# Generation: 454, Best fitness: 40.0
# Generation: 455, Best fitness: 40.0
# Generation: 456, Best fitness: 40.0
# Generation: 457, Best fitness: 40.0
# Generation: 458, Best fitness: 40.0
# Generation: 459, Best fitness: 40.0
# Generation: 460, Best fitness: 40.0
# Generation: 461, Best fitness: 40.0
# Generation: 462, Best fitness: 40.0
# Generation: 463, Best fitness: 40.0
# Generation: 464, Best fitness: 40.0
# Generation: 465, Best fitness: 40.0
# Generation: 466, Best fitness: 40.0
# Generation: 467, Best fitness: 40.0
# Generation: 468, Best fitness: 40.0
# Generation: 469, Best fitness: 40.0
# Generation: 470, Best fitness: 40.0
# Generation: 471, Best fitness: 40.0
# Generation: 472, Best fitness: 40.0
# Generation: 473, Best fitness: 40.0
# Generation: 474, Best fitness: 40.0
# Generation: 475, Best fitness: 40.0
# Generation: 476, Best fitness: 40.0
# Generation: 477, Best fitness: 40.0
# Generation: 478, Best fitness: 40.0
# Generation: 479, Best fitness: 40.0
# Generation: 480, Best fitness: 40.0
# Generation: 481, Best fitness: 40.0
# Generation: 482, Best fitness: 40.0
# Generation: 483, Best fitness: 40.0
# Generation: 484, Best fitness: 40.0
# Generation: 485, Best fitness: 40.0
# Generation: 486, Best fitness: 40.0
# Generation: 487, Best fitness: 40.0
# Generation: 488, Best fitness: 40.0
# Generation: 489, Best fitness: 40.0
# Generation: 490, Best fitness: 40.0
# Generation: 491, Best fitness: 40.0
# Generation: 492, Best fitness: 40.0
# Generation: 493, Best fitness: 40.0
# Generation: 494, Best fitness: 40.0
# Generation: 495, Best fitness: 40.0
# Generation: 496, Best fitness: 40.0
# Generation: 497, Best fitness: 40.0
# Generation: 498, Best fitness: 40.0
# Generation: 499, Best fitness: 40.0
# Generation: 500, Best fitness: 40.0
# Generation: 501, Best fitness: 40.0
# Generation: 502, Best fitness: 40.0
# Generation: 503, Best fitness: 40.0
# Generation: 504, Best fitness: 40.0
# Generation: 505, Best fitness: 40.0
# Generation: 506, Best fitness: 40.0
# Generation: 507, Best fitness: 40.0
# Generation: 508, Best fitness: 40.0
# Generation: 509, Best fitness: 40.0
# Generation: 510, Best fitness: 40.0
# Generation: 511, Best fitness: 40.0
# Generation: 512, Best fitness: 40.0
# Generation: 513, Best fitness: 40.0
# Generation: 514, Best fitness: 40.0
# Generation: 515, Best fitness: 40.0
# Generation: 516, Best fitness: 40.0
# Generation: 517, Best fitness: 40.0
# Generation: 518, Best fitness: 40.0
# Generation: 519, Best fitness: 40.0
# Generation: 520, Best fitness: 40.0
# Generation: 521, Best fitness: 40.0
# Generation: 522, Best fitness: 40.0
# Generation: 523, Best fitness: 40.0
# Generation: 524, Best fitness: 40.0
# Generation: 525, Best fitness: 50.0
# Generation: 526, Best fitness: 40.0
# Generation: 527, Best fitness: 40.0
# Generation: 528, Best fitness: 40.0
# Generation: 529, Best fitness: 40.0
# Generation: 530, Best fitness: 40.0
# Generation: 531, Best fitness: 40.0
# Generation: 532, Best fitness: 40.0
# Generation: 533, Best fitness: 40.0
# Generation: 534, Best fitness: 40.0
# Generation: 535, Best fitness: 40.0
# Generation: 536, Best fitness: 50.0
# Generation: 537, Best fitness: 50.0
# Generation: 538, Best fitness: 50.0
# Generation: 539, Best fitness: 40.0
# Generation: 540, Best fitness: 50.0
# Generation: 541, Best fitness: 50.0
# Generation: 542, Best fitness: 50.0
# Generation: 543, Best fitness: 40.0
# Generation: 544, Best fitness: 40.0
# Generation: 545, Best fitness: 40.0
# Generation: 546, Best fitness: 40.0
# Generation: 547, Best fitness: 40.0
# Generation: 548, Best fitness: 40.0
# Generation: 549, Best fitness: 40.0
# Generation: 550, Best fitness: 40.0
# Generation: 551, Best fitness: 40.0
# Generation: 552, Best fitness: 40.0
# Generation: 553, Best fitness: 40.0
# Generation: 554, Best fitness: 40.0
# Generation: 555, Best fitness: 40.0
# Generation: 556, Best fitness: 40.0
# Generation: 557, Best fitness: 40.0
# Generation: 558, Best fitness: 40.0
# Generation: 559, Best fitness: 40.0
# Generation: 560, Best fitness: 40.0
# Generation: 561, Best fitness: 40.0
# Generation: 562, Best fitness: 40.0
# Generation: 563, Best fitness: 40.0
# Generation: 564, Best fitness: 40.0
# Generation: 565, Best fitness: 40.0
# Generation: 566, Best fitness: 40.0
# Generation: 567, Best fitness: 40.0
# Generation: 568, Best fitness: 40.0
# Generation: 569, Best fitness: 40.0
# Generation: 570, Best fitness: 40.0
# Generation: 571, Best fitness: 40.0
# Generation: 572, Best fitness: 40.0
# Generation: 573, Best fitness: 40.0
# Generation: 574, Best fitness: 40.0
# Generation: 575, Best fitness: 40.0
# Generation: 576, Best fitness: 40.0
# Generation: 577, Best fitness: 40.0
# Generation: 578, Best fitness: 40.0
# Generation: 579, Best fitness: 40.0
# Generation: 580, Best fitness: 40.0
# Generation: 581, Best fitness: 40.0
# Generation: 582, Best fitness: 50.0
# Generation: 583, Best fitness: 50.0
# Generation: 584, Best fitness: 40.0
# Generation: 585, Best fitness: 40.0
# Generation: 586, Best fitness: 40.0
# Generation: 587, Best fitness: 40.0
# Generation: 588, Best fitness: 40.0
# Generation: 589, Best fitness: 40.0
# Generation: 590, Best fitness: 40.0
# Generation: 591, Best fitness: 40.0
# Generation: 592, Best fitness: 40.0
# Generation: 593, Best fitness: 40.0
# Generation: 594, Best fitness: 40.0
# Generation: 595, Best fitness: 40.0
# Generation: 596, Best fitness: 40.0
# Generation: 597, Best fitness: 40.0
# Generation: 598, Best fitness: 40.0
# Generation: 599, Best fitness: 40.0
# Generation: 600, Best fitness: 40.0
# Generation: 601, Best fitness: 40.0
# Generation: 602, Best fitness: 40.0
# Generation: 603, Best fitness: 40.0
# Generation: 604, Best fitness: 40.0
# Generation: 605, Best fitness: 40.0
# Generation: 606, Best fitness: 40.0
# Generation: 607, Best fitness: 40.0
# Generation: 608, Best fitness: 40.0
# Generation: 609, Best fitness: 40.0
# Generation: 610, Best fitness: 40.0
# Generation: 611, Best fitness: 40.0
# Generation: 612, Best fitness: 40.0
# Generation: 613, Best fitness: 40.0
# Generation: 614, Best fitness: 40.0
# Generation: 615, Best fitness: 40.0
# Generation: 616, Best fitness: 40.0
# Generation: 617, Best fitness: 40.0
# Generation: 618, Best fitness: 40.0
# Generation: 619, Best fitness: 40.0
# Generation: 620, Best fitness: 40.0
# Generation: 621, Best fitness: 40.0
# Generation: 622, Best fitness: 40.0
# Generation: 623, Best fitness: 50.0
# Generation: 624, Best fitness: 50.0
# Generation: 625, Best fitness: 50.0
# Generation: 626, Best fitness: 40.0
# Generation: 627, Best fitness: 40.0
# Generation: 628, Best fitness: 40.0
# Generation: 629, Best fitness: 40.0
# Generation: 630, Best fitness: 40.0
# Generation: 631, Best fitness: 40.0
# Generation: 632, Best fitness: 40.0
# Generation: 633, Best fitness: 40.0
# Generation: 634, Best fitness: 40.0
# Generation: 635, Best fitness: 40.0
# Generation: 636, Best fitness: 40.0
# Generation: 637, Best fitness: 40.0
# Generation: 638, Best fitness: 40.0
# Generation: 639, Best fitness: 40.0
# Generation: 640, Best fitness: 40.0
# Generation: 641, Best fitness: 40.0
# Generation: 642, Best fitness: 40.0
# Generation: 643, Best fitness: 40.0
# Generation: 644, Best fitness: 40.0
# Generation: 645, Best fitness: 40.0
# Generation: 646, Best fitness: 40.0
# Generation: 647, Best fitness: 40.0
# Generation: 648, Best fitness: 40.0
# Generation: 649, Best fitness: 40.0
# Generation: 650, Best fitness: 40.0
# Generation: 651, Best fitness: 40.0
# Generation: 652, Best fitness: 40.0
# Generation: 653, Best fitness: 40.0
# Generation: 654, Best fitness: 40.0
# Generation: 655, Best fitness: 40.0
# Generation: 656, Best fitness: 40.0
# Generation: 657, Best fitness: 40.0
# Generation: 658, Best fitness: 40.0
# Generation: 659, Best fitness: 40.0
# Generation: 660, Best fitness: 40.0
# Generation: 661, Best fitness: 40.0
# Generation: 662, Best fitness: 40.0
# Generation: 663, Best fitness: 40.0
# Generation: 664, Best fitness: 50.0
# Generation: 665, Best fitness: 50.0
# Generation: 666, Best fitness: 50.0
# Generation: 667, Best fitness: 50.0
# Generation: 668, Best fitness: 40.0
# Generation: 669, Best fitness: 40.0
# Generation: 670, Best fitness: 40.0
# Generation: 671, Best fitness: 40.0
# Generation: 672, Best fitness: 40.0
# Generation: 673, Best fitness: 40.0
# Generation: 674, Best fitness: 40.0
# Generation: 675, Best fitness: 40.0
# Generation: 676, Best fitness: 40.0
# Generation: 677, Best fitness: 40.0
# Generation: 678, Best fitness: 40.0
# Generation: 679, Best fitness: 40.0
# Generation: 680, Best fitness: 40.0
# Generation: 681, Best fitness: 40.0
# Generation: 682, Best fitness: 40.0
# Generation: 683, Best fitness: 40.0
# Generation: 684, Best fitness: 40.0
# Generation: 685, Best fitness: 40.0
# Generation: 686, Best fitness: 40.0
# Generation: 687, Best fitness: 40.0
# Generation: 688, Best fitness: 40.0
# Generation: 689, Best fitness: 40.0
# Generation: 690, Best fitness: 40.0
# Generation: 691, Best fitness: 40.0
# Generation: 692, Best fitness: 40.0
# Generation: 693, Best fitness: 40.0
# Generation: 694, Best fitness: 40.0
# Generation: 695, Best fitness: 40.0
# Generation: 696, Best fitness: 40.0
# Generation: 697, Best fitness: 40.0
# Generation: 698, Best fitness: 40.0
# Generation: 699, Best fitness: 40.0
# Generation: 700, Best fitness: 40.0
# Generation: 701, Best fitness: 40.0
# Generation: 702, Best fitness: 40.0
# Generation: 703, Best fitness: 40.0
# Generation: 704, Best fitness: 40.0
# Generation: 705, Best fitness: 40.0
# Generation: 706, Best fitness: 40.0
# Generation: 707, Best fitness: 40.0
# Generation: 708, Best fitness: 50.0
# Generation: 709, Best fitness: 50.0
# Generation: 710, Best fitness: 40.0
# Generation: 711, Best fitness: 40.0
# Generation: 712, Best fitness: 40.0
# Generation: 713, Best fitness: 40.0
# Generation: 714, Best fitness: 40.0
# Generation: 715, Best fitness: 50.0
# Generation: 716, Best fitness: 40.0
# Generation: 717, Best fitness: 40.0
# Generation: 718, Best fitness: 40.0
# Generation: 719, Best fitness: 40.0
# Generation: 720, Best fitness: 40.0
# Generation: 721, Best fitness: 40.0
# Generation: 722, Best fitness: 40.0
# Generation: 723, Best fitness: 40.0
# Generation: 724, Best fitness: 40.0
# Generation: 725, Best fitness: 40.0
# Generation: 726, Best fitness: 40.0
# Generation: 727, Best fitness: 40.0
# Generation: 728, Best fitness: 40.0
# Generation: 729, Best fitness: 40.0
# Generation: 730, Best fitness: 40.0
# Generation: 731, Best fitness: 40.0
# Generation: 732, Best fitness: 40.0
# Generation: 733, Best fitness: 40.0
# Generation: 734, Best fitness: 40.0
# Generation: 735, Best fitness: 40.0
# Generation: 736, Best fitness: 40.0
# Generation: 737, Best fitness: 40.0
# Generation: 738, Best fitness: 40.0
# Generation: 739, Best fitness: 40.0
# Generation: 740, Best fitness: 40.0
# Generation: 741, Best fitness: 40.0
# Generation: 742, Best fitness: 40.0
# Generation: 743, Best fitness: 40.0
# Generation: 744, Best fitness: 40.0
# Generation: 745, Best fitness: 40.0
# Generation: 746, Best fitness: 40.0
# Generation: 747, Best fitness: 40.0
# Generation: 748, Best fitness: 40.0
# Generation: 749, Best fitness: 40.0
# Generation: 750, Best fitness: 40.0
# Generation: 751, Best fitness: 40.0
# Generation: 752, Best fitness: 40.0
# Generation: 753, Best fitness: 40.0
# Generation: 754, Best fitness: 40.0
# Generation: 755, Best fitness: 40.0
# Generation: 756, Best fitness: 40.0
# Generation: 757, Best fitness: 40.0
# Generation: 758, Best fitness: 40.0
# Generation: 759, Best fitness: 40.0
# Generation: 760, Best fitness: 40.0
# Generation: 761, Best fitness: 40.0
# Generation: 762, Best fitness: 40.0
# Generation: 763, Best fitness: 40.0
# Generation: 764, Best fitness: 40.0
# Generation: 765, Best fitness: 40.0
# Generation: 766, Best fitness: 40.0
# Generation: 767, Best fitness: 40.0
# Generation: 768, Best fitness: 40.0
# Generation: 769, Best fitness: 40.0
# Generation: 770, Best fitness: 40.0
# Generation: 771, Best fitness: 40.0
# Generation: 772, Best fitness: 40.0
# Generation: 773, Best fitness: 40.0
# Generation: 774, Best fitness: 40.0
# Generation: 775, Best fitness: 50.0
# Generation: 776, Best fitness: 50.0
# Generation: 777, Best fitness: 40.0
# Generation: 778, Best fitness: 40.0
# Generation: 779, Best fitness: 40.0
# Generation: 780, Best fitness: 50.0
# Generation: 781, Best fitness: 50.0
# Generation: 782, Best fitness: 50.0
# Generation: 783, Best fitness: 50.0
# Generation: 784, Best fitness: 50.0
# Generation: 785, Best fitness: 40.0
# Generation: 786, Best fitness: 40.0
# Generation: 787, Best fitness: 40.0
# Generation: 788, Best fitness: 40.0
# Generation: 789, Best fitness: 40.0
# Generation: 790, Best fitness: 50.0
# Generation: 791, Best fitness: 40.0
# Generation: 792, Best fitness: 40.0
# Generation: 793, Best fitness: 40.0
# Generation: 794, Best fitness: 40.0
# Generation: 795, Best fitness: 40.0
# Generation: 796, Best fitness: 40.0
# Generation: 797, Best fitness: 40.0
# Generation: 798, Best fitness: 40.0
# Generation: 799, Best fitness: 40.0
# Generation: 800, Best fitness: 40.0
# Generation: 801, Best fitness: 40.0
# Generation: 802, Best fitness: 40.0
# Generation: 803, Best fitness: 40.0
# Generation: 804, Best fitness: 40.0
# Generation: 805, Best fitness: 40.0
# Generation: 806, Best fitness: 40.0
# Generation: 807, Best fitness: 40.0
# Generation: 808, Best fitness: 40.0
# Generation: 809, Best fitness: 40.0
# Generation: 810, Best fitness: 40.0
# Generation: 811, Best fitness: 40.0
# Generation: 812, Best fitness: 40.0
# Generation: 813, Best fitness: 40.0
# Generation: 814, Best fitness: 40.0
# Generation: 815, Best fitness: 40.0
# Generation: 816, Best fitness: 40.0
# Generation: 817, Best fitness: 40.0
# Generation: 818, Best fitness: 40.0
# Generation: 819, Best fitness: 40.0
# Generation: 820, Best fitness: 40.0
# Generation: 821, Best fitness: 40.0
# Generation: 822, Best fitness: 40.0
# Generation: 823, Best fitness: 40.0
# Generation: 824, Best fitness: 40.0
# Generation: 825, Best fitness: 40.0
# Generation: 826, Best fitness: 50.0
# Generation: 827, Best fitness: 40.0
# Generation: 828, Best fitness: 40.0
# Generation: 829, Best fitness: 40.0
# Generation: 830, Best fitness: 40.0
# Generation: 831, Best fitness: 40.0
# Generation: 832, Best fitness: 40.0
# Generation: 833, Best fitness: 40.0
# Generation: 834, Best fitness: 40.0
# Generation: 835, Best fitness: 40.0
# Generation: 836, Best fitness: 40.0
# Generation: 837, Best fitness: 40.0
# Generation: 838, Best fitness: 40.0
# Generation: 839, Best fitness: 40.0
# Generation: 840, Best fitness: 40.0
# Generation: 841, Best fitness: 40.0
# Generation: 842, Best fitness: 40.0
# Generation: 843, Best fitness: 50.0
# Generation: 844, Best fitness: 50.0
# Generation: 845, Best fitness: 50.0
# Generation: 846, Best fitness: 40.0
# Generation: 847, Best fitness: 40.0
# Generation: 848, Best fitness: 40.0
# Generation: 849, Best fitness: 50.0
# Generation: 850, Best fitness: 40.0
# Generation: 851, Best fitness: 40.0
# Generation: 852, Best fitness: 40.0
# Generation: 853, Best fitness: 40.0
# Generation: 854, Best fitness: 40.0
# Generation: 855, Best fitness: 40.0
# Generation: 856, Best fitness: 40.0
# Generation: 857, Best fitness: 40.0
# Generation: 858, Best fitness: 40.0
# Generation: 859, Best fitness: 40.0
# Generation: 860, Best fitness: 40.0
# Generation: 861, Best fitness: 40.0
# Generation: 862, Best fitness: 40.0
# Generation: 863, Best fitness: 40.0
# Generation: 864, Best fitness: 40.0
# Generation: 865, Best fitness: 40.0
# Generation: 866, Best fitness: 40.0
# Generation: 867, Best fitness: 40.0
# Generation: 868, Best fitness: 40.0
# Generation: 869, Best fitness: 40.0
# Generation: 870, Best fitness: 40.0
# Generation: 871, Best fitness: 40.0
# Generation: 872, Best fitness: 40.0
# Generation: 873, Best fitness: 40.0
# Generation: 874, Best fitness: 40.0
# Generation: 875, Best fitness: 40.0
# Generation: 876, Best fitness: 40.0
# Generation: 877, Best fitness: 40.0
# Generation: 878, Best fitness: 40.0
# Generation: 879, Best fitness: 40.0
# Generation: 880, Best fitness: 40.0
# Generation: 881, Best fitness: 40.0
# Generation: 882, Best fitness: 40.0
# Generation: 883, Best fitness: 40.0
# Generation: 884, Best fitness: 40.0
# Generation: 885, Best fitness: 40.0
# Generation: 886, Best fitness: 40.0
# Generation: 887, Best fitness: 40.0
# Generation: 888, Best fitness: 40.0
# Generation: 889, Best fitness: 40.0
# Generation: 890, Best fitness: 40.0
# Generation: 891, Best fitness: 40.0
# Generation: 892, Best fitness: 40.0
# Generation: 893, Best fitness: 40.0
# Generation: 894, Best fitness: 40.0
# Generation: 895, Best fitness: 40.0
# Generation: 896, Best fitness: 40.0
# Generation: 897, Best fitness: 40.0
# Generation: 898, Best fitness: 40.0
# Generation: 899, Best fitness: 40.0
# Generation: 900, Best fitness: 40.0
# Generation: 901, Best fitness: 50.0
# Generation: 902, Best fitness: 40.0
# Generation: 903, Best fitness: 40.0
# Generation: 904, Best fitness: 50.0
# Generation: 905, Best fitness: 40.0
# Generation: 906, Best fitness: 50.0
# Generation: 907, Best fitness: 50.0
# Generation: 908, Best fitness: 40.0
# Generation: 909, Best fitness: 40.0
# Generation: 910, Best fitness: 40.0
# Generation: 911, Best fitness: 40.0
# Generation: 912, Best fitness: 40.0
# Generation: 913, Best fitness: 40.0
# Generation: 914, Best fitness: 40.0
# Generation: 915, Best fitness: 40.0
# Generation: 916, Best fitness: 40.0
# Generation: 917, Best fitness: 40.0
# Generation: 918, Best fitness: 40.0
# Generation: 919, Best fitness: 40.0
# Generation: 920, Best fitness: 40.0
# Generation: 921, Best fitness: 50.0
# Generation: 922, Best fitness: 40.0
# Generation: 923, Best fitness: 40.0
# Generation: 924, Best fitness: 40.0
# Generation: 925, Best fitness: 40.0
# Generation: 926, Best fitness: 40.0
# Generation: 927, Best fitness: 40.0
# Generation: 928, Best fitness: 40.0
# Generation: 929, Best fitness: 40.0
# Generation: 930, Best fitness: 40.0
# Generation: 931, Best fitness: 40.0
# Generation: 932, Best fitness: 40.0
# Generation: 933, Best fitness: 40.0
# Generation: 934, Best fitness: 40.0
# Generation: 935, Best fitness: 40.0
# Generation: 936, Best fitness: 40.0
# Generation: 937, Best fitness: 40.0
# Generation: 938, Best fitness: 40.0
# Generation: 939, Best fitness: 40.0
# Generation: 940, Best fitness: 40.0
# Generation: 941, Best fitness: 40.0
# Generation: 942, Best fitness: 40.0
# Generation: 943, Best fitness: 40.0
# Generation: 944, Best fitness: 40.0
# Generation: 945, Best fitness: 40.0
# Generation: 946, Best fitness: 40.0
# Generation: 947, Best fitness: 40.0
# Generation: 948, Best fitness: 40.0
# Generation: 949, Best fitness: 40.0
# Generation: 950, Best fitness: 40.0
# Generation: 951, Best fitness: 40.0
# Generation: 952, Best fitness: 40.0
# Generation: 953, Best fitness: 40.0
# Generation: 954, Best fitness: 50.0
# Generation: 955, Best fitness: 40.0
# Generation: 956, Best fitness: 40.0
# Generation: 957, Best fitness: 40.0
# Generation: 958, Best fitness: 40.0
# Generation: 959, Best fitness: 40.0
# Generation: 960, Best fitness: 40.0
# Generation: 961, Best fitness: 40.0
# Generation: 962, Best fitness: 40.0
# Generation: 963, Best fitness: 40.0
# Generation: 964, Best fitness: 40.0
# Generation: 965, Best fitness: 40.0
# Generation: 966, Best fitness: 40.0
# Generation: 967, Best fitness: 40.0
# Generation: 968, Best fitness: 40.0
# Generation: 969, Best fitness: 40.0
# Generation: 970, Best fitness: 40.0
# Generation: 971, Best fitness: 40.0
# Generation: 972, Best fitness: 40.0
# Generation: 973, Best fitness: 40.0
# Generation: 974, Best fitness: 40.0
# Generation: 975, Best fitness: 40.0
# Generation: 976, Best fitness: 40.0
# Generation: 977, Best fitness: 40.0
# Generation: 978, Best fitness: 40.0
# Generation: 979, Best fitness: 40.0
# Generation: 980, Best fitness: 40.0
# Generation: 981, Best fitness: 40.0
# Generation: 982, Best fitness: 40.0
# Generation: 983, Best fitness: 40.0
# Generation: 984, Best fitness: 40.0
# Generation: 985, Best fitness: 40.0
# Generation: 986, Best fitness: 40.0
# Generation: 987, Best fitness: 40.0
# Generation: 988, Best fitness: 40.0
# Generation: 989, Best fitness: 40.0
# Generation: 990, Best fitness: 40.0
# Generation: 991, Best fitness: 40.0
# Generation: 992, Best fitness: 40.0
# Generation: 993, Best fitness: 40.0
# Generation: 994, Best fitness: 40.0
# Generation: 995, Best fitness: 40.0
# Generation: 996, Best fitness: 40.0
# Generation: 997, Best fitness: 40.0
# Generation: 998, Best fitness: 40.0
# Generation: 999, Best fitness: 40.0
# Average makespan for task size 200: 51.461352053146136
# Optimizing for task size: 500
# Generation: 0, Best fitness: 100.0
# Generation: 1, Best fitness: 100.0
# Generation: 2, Best fitness: 100.0
# Generation: 3, Best fitness: 100.0
# Generation: 4, Best fitness: 100.0
# Generation: 5, Best fitness: 100.0
# Generation: 6, Best fitness: 100.0
# Generation: 7, Best fitness: 100.0
# Generation: 8, Best fitness: 100.0
# Generation: 9, Best fitness: 100.0
# Generation: 10, Best fitness: 100.0
# Generation: 11, Best fitness: 100.0
# Generation: 12, Best fitness: 100.0
# Generation: 13, Best fitness: 100.0
# Generation: 14, Best fitness: 100.0
# Generation: 15, Best fitness: 100.0
# Generation: 16, Best fitness: 100.0
# Generation: 17, Best fitness: 100.0
# Generation: 18, Best fitness: 100.0
# Generation: 19, Best fitness: 100.0
# Generation: 20, Best fitness: 100.0
# Generation: 21, Best fitness: 100.0
# Generation: 22, Best fitness: 100.0
# Generation: 23, Best fitness: 100.0
# Generation: 24, Best fitness: 100.0
# Generation: 25, Best fitness: 100.0
# Generation: 26, Best fitness: 100.0
# Generation: 27, Best fitness: 100.0
# Generation: 28, Best fitness: 100.0
# Generation: 29, Best fitness: 100.0
# Generation: 30, Best fitness: 100.0
# Generation: 31, Best fitness: 100.0
# Generation: 32, Best fitness: 125.0
# Generation: 33, Best fitness: 125.0
# Generation: 34, Best fitness: 125.0
# Generation: 35, Best fitness: 125.0
# Generation: 36, Best fitness: 125.0
# Generation: 37, Best fitness: 125.0
# Generation: 38, Best fitness: 100.0
# Generation: 39, Best fitness: 100.0
# Generation: 40, Best fitness: 100.0
# Generation: 41, Best fitness: 100.0
# Generation: 42, Best fitness: 100.0
# Generation: 43, Best fitness: 100.0
# Generation: 44, Best fitness: 100.0
# Generation: 45, Best fitness: 100.0
# Generation: 46, Best fitness: 100.0
# Generation: 47, Best fitness: 100.0
# Generation: 48, Best fitness: 100.0
# Generation: 49, Best fitness: 100.0
# Generation: 50, Best fitness: 100.0
# Generation: 51, Best fitness: 100.0
# Generation: 52, Best fitness: 100.0
# Generation: 53, Best fitness: 100.0
# Generation: 54, Best fitness: 100.0
# Generation: 55, Best fitness: 100.0
# Generation: 56, Best fitness: 100.0
# Generation: 57, Best fitness: 100.0
# Generation: 58, Best fitness: 100.0
# Generation: 59, Best fitness: 100.0
# Generation: 60, Best fitness: 100.0
# Generation: 61, Best fitness: 100.0
# Generation: 62, Best fitness: 100.0
# Generation: 63, Best fitness: 100.0
# Generation: 64, Best fitness: 100.0
# Generation: 65, Best fitness: 100.0
# Generation: 66, Best fitness: 100.0
# Generation: 67, Best fitness: 100.0
# Generation: 68, Best fitness: 125.0
# Generation: 69, Best fitness: 100.0
# Generation: 70, Best fitness: 100.0
# Generation: 71, Best fitness: 125.0
# Generation: 72, Best fitness: 100.0
# Generation: 73, Best fitness: 100.0
# Generation: 74, Best fitness: 100.0
# Generation: 75, Best fitness: 100.0
# Generation: 76, Best fitness: 100.0
# Generation: 77, Best fitness: 100.0
# Generation: 78, Best fitness: 100.0
# Generation: 79, Best fitness: 100.0
# Generation: 80, Best fitness: 100.0
# Generation: 81, Best fitness: 100.0
# Generation: 82, Best fitness: 100.0
# Generation: 83, Best fitness: 100.0
# Generation: 84, Best fitness: 100.0
# Generation: 85, Best fitness: 100.0
# Generation: 86, Best fitness: 100.0
# Generation: 87, Best fitness: 100.0
# Generation: 88, Best fitness: 100.0
# Generation: 89, Best fitness: 100.0
# Generation: 90, Best fitness: 100.0
# Generation: 91, Best fitness: 100.0
# Generation: 92, Best fitness: 100.0
# Generation: 93, Best fitness: 100.0
# Generation: 94, Best fitness: 100.0
# Generation: 95, Best fitness: 100.0
# Generation: 96, Best fitness: 100.0
# Generation: 97, Best fitness: 100.0
# Generation: 98, Best fitness: 100.0
# Generation: 99, Best fitness: 100.0
# Generation: 100, Best fitness: 100.0
# Generation: 101, Best fitness: 100.0
# Generation: 102, Best fitness: 100.0
# Generation: 103, Best fitness: 100.0
# Generation: 104, Best fitness: 100.0
# Generation: 105, Best fitness: 100.0
# Generation: 106, Best fitness: 100.0
# Generation: 107, Best fitness: 100.0
# Generation: 108, Best fitness: 100.0
# Generation: 109, Best fitness: 100.0
# Generation: 110, Best fitness: 100.0
# Generation: 111, Best fitness: 100.0
# Generation: 112, Best fitness: 100.0
# Generation: 113, Best fitness: 100.0
# Generation: 114, Best fitness: 100.0
# Generation: 115, Best fitness: 100.0
# Generation: 116, Best fitness: 100.0
# Generation: 117, Best fitness: 100.0
# Generation: 118, Best fitness: 100.0
# Generation: 119, Best fitness: 100.0
# Generation: 120, Best fitness: 100.0
# Generation: 121, Best fitness: 100.0
# Generation: 122, Best fitness: 100.0
# Generation: 123, Best fitness: 100.0
# Generation: 124, Best fitness: 100.0
# Generation: 125, Best fitness: 100.0
# Generation: 126, Best fitness: 100.0
# Generation: 127, Best fitness: 100.0
# Generation: 128, Best fitness: 100.0
# Generation: 129, Best fitness: 100.0
# Generation: 130, Best fitness: 100.0
# Generation: 131, Best fitness: 100.0
# Generation: 132, Best fitness: 100.0
# Generation: 133, Best fitness: 100.0
# Generation: 134, Best fitness: 100.0
# Generation: 135, Best fitness: 100.0
# Generation: 136, Best fitness: 100.0
# Generation: 137, Best fitness: 100.0
# Generation: 138, Best fitness: 100.0
# Generation: 139, Best fitness: 100.0
# Generation: 140, Best fitness: 100.0
# Generation: 141, Best fitness: 100.0
# Generation: 142, Best fitness: 100.0
# Generation: 143, Best fitness: 100.0
# Generation: 144, Best fitness: 100.0
# Generation: 145, Best fitness: 100.0
# Generation: 146, Best fitness: 100.0
# Generation: 147, Best fitness: 100.0
# Generation: 148, Best fitness: 100.0
# Generation: 149, Best fitness: 100.0
# Generation: 150, Best fitness: 100.0
# Generation: 151, Best fitness: 100.0
# Generation: 152, Best fitness: 100.0
# Generation: 153, Best fitness: 100.0
# Generation: 154, Best fitness: 100.0
# Generation: 155, Best fitness: 100.0
# Generation: 156, Best fitness: 100.0
# Generation: 157, Best fitness: 100.0
# Generation: 158, Best fitness: 100.0
# Generation: 159, Best fitness: 100.0
# Generation: 160, Best fitness: 100.0
# Generation: 161, Best fitness: 100.0
# Generation: 162, Best fitness: 100.0
# Generation: 163, Best fitness: 100.0
# Generation: 164, Best fitness: 100.0
# Generation: 165, Best fitness: 100.0
# Generation: 166, Best fitness: 100.0
# Generation: 167, Best fitness: 100.0
# Generation: 168, Best fitness: 100.0
# Generation: 169, Best fitness: 100.0
# Generation: 170, Best fitness: 100.0
# Generation: 171, Best fitness: 100.0
# Generation: 172, Best fitness: 100.0
# Generation: 173, Best fitness: 100.0
# Generation: 174, Best fitness: 100.0
# Generation: 175, Best fitness: 100.0
# Generation: 176, Best fitness: 100.0
# Generation: 177, Best fitness: 100.0
# Generation: 178, Best fitness: 100.0
# Generation: 179, Best fitness: 100.0
# Generation: 180, Best fitness: 100.0
# Generation: 181, Best fitness: 100.0
# Generation: 182, Best fitness: 100.0
# Generation: 183, Best fitness: 100.0
# Generation: 184, Best fitness: 100.0
# Generation: 185, Best fitness: 100.0
# Generation: 186, Best fitness: 100.0
# Generation: 187, Best fitness: 100.0
# Generation: 188, Best fitness: 100.0
# Generation: 189, Best fitness: 100.0
# Generation: 190, Best fitness: 100.0
# Generation: 191, Best fitness: 100.0
# Generation: 192, Best fitness: 100.0
# Generation: 193, Best fitness: 100.0
# Generation: 194, Best fitness: 100.0
# Generation: 195, Best fitness: 100.0
# Generation: 196, Best fitness: 100.0
# Generation: 197, Best fitness: 100.0
# Generation: 198, Best fitness: 100.0
# Generation: 199, Best fitness: 100.0
# Generation: 200, Best fitness: 100.0
# Generation: 201, Best fitness: 100.0
# Generation: 202, Best fitness: 100.0
# Generation: 203, Best fitness: 100.0
# Generation: 204, Best fitness: 100.0
# Generation: 205, Best fitness: 100.0
# Generation: 206, Best fitness: 125.0
# Generation: 207, Best fitness: 125.0
# Generation: 208, Best fitness: 100.0
# Generation: 209, Best fitness: 100.0
# Generation: 210, Best fitness: 100.0
# Generation: 211, Best fitness: 100.0
# Generation: 212, Best fitness: 100.0
# Generation: 213, Best fitness: 100.0
# Generation: 214, Best fitness: 100.0
# Generation: 215, Best fitness: 100.0
# Generation: 216, Best fitness: 100.0
# Generation: 217, Best fitness: 100.0
# Generation: 218, Best fitness: 100.0
# Generation: 219, Best fitness: 100.0
# Generation: 220, Best fitness: 125.0
# Generation: 221, Best fitness: 100.0
# Generation: 222, Best fitness: 100.0
# Generation: 223, Best fitness: 100.0
# Generation: 224, Best fitness: 100.0
# Generation: 225, Best fitness: 100.0
# Generation: 226, Best fitness: 100.0
# Generation: 227, Best fitness: 100.0
# Generation: 228, Best fitness: 100.0
# Generation: 229, Best fitness: 100.0
# Generation: 230, Best fitness: 100.0
# Generation: 231, Best fitness: 100.0
# Generation: 232, Best fitness: 100.0
# Generation: 233, Best fitness: 100.0
# Generation: 234, Best fitness: 100.0
# Generation: 235, Best fitness: 100.0
# Generation: 236, Best fitness: 100.0
# Generation: 237, Best fitness: 100.0
# Generation: 238, Best fitness: 100.0
# Generation: 239, Best fitness: 100.0
# Generation: 240, Best fitness: 100.0
# Generation: 241, Best fitness: 100.0
# Generation: 242, Best fitness: 100.0
# Generation: 243, Best fitness: 100.0
# Generation: 244, Best fitness: 100.0
# Generation: 245, Best fitness: 100.0
# Generation: 246, Best fitness: 100.0
# Generation: 247, Best fitness: 100.0
# Generation: 248, Best fitness: 100.0
# Generation: 249, Best fitness: 100.0
# Generation: 250, Best fitness: 100.0
# Generation: 251, Best fitness: 100.0
# Generation: 252, Best fitness: 100.0
# Generation: 253, Best fitness: 100.0
# Generation: 254, Best fitness: 100.0
# Generation: 255, Best fitness: 100.0
# Generation: 256, Best fitness: 100.0
# Generation: 257, Best fitness: 100.0
# Generation: 258, Best fitness: 100.0
# Generation: 259, Best fitness: 100.0
# Generation: 260, Best fitness: 100.0
# Generation: 261, Best fitness: 100.0
# Generation: 262, Best fitness: 125.0
# Generation: 263, Best fitness: 125.0
# Generation: 264, Best fitness: 125.0
# Generation: 265, Best fitness: 125.0
# Generation: 266, Best fitness: 125.0
# Generation: 267, Best fitness: 100.0
# Generation: 268, Best fitness: 100.0
# Generation: 269, Best fitness: 100.0
# Generation: 270, Best fitness: 100.0
# Generation: 271, Best fitness: 100.0
# Generation: 272, Best fitness: 100.0
# Generation: 273, Best fitness: 100.0
# Generation: 274, Best fitness: 100.0
# Generation: 275, Best fitness: 100.0
# Generation: 276, Best fitness: 100.0
# Generation: 277, Best fitness: 100.0
# Generation: 278, Best fitness: 100.0
# Generation: 279, Best fitness: 100.0
# Generation: 280, Best fitness: 100.0
# Generation: 281, Best fitness: 100.0
# Generation: 282, Best fitness: 100.0
# Generation: 283, Best fitness: 100.0
# Generation: 284, Best fitness: 100.0
# Generation: 285, Best fitness: 100.0
# Generation: 286, Best fitness: 100.0
# Generation: 287, Best fitness: 100.0
# Generation: 288, Best fitness: 125.0
# Generation: 289, Best fitness: 100.0
# Generation: 290, Best fitness: 125.0
# Generation: 291, Best fitness: 125.0
# Generation: 292, Best fitness: 100.0
# Generation: 293, Best fitness: 100.0
# Generation: 294, Best fitness: 100.0
# Generation: 295, Best fitness: 100.0
# Generation: 296, Best fitness: 100.0
# Generation: 297, Best fitness: 100.0
# Generation: 298, Best fitness: 100.0
# Generation: 299, Best fitness: 100.0
# Generation: 300, Best fitness: 100.0
# Generation: 301, Best fitness: 100.0
# Generation: 302, Best fitness: 100.0
# Generation: 303, Best fitness: 100.0
# Generation: 304, Best fitness: 100.0
# Generation: 305, Best fitness: 100.0
# Generation: 306, Best fitness: 100.0
# Generation: 307, Best fitness: 100.0
# Generation: 308, Best fitness: 100.0
# Generation: 309, Best fitness: 100.0
# Generation: 310, Best fitness: 100.0
# Generation: 311, Best fitness: 100.0
# Generation: 312, Best fitness: 100.0
# Generation: 313, Best fitness: 100.0
# Generation: 314, Best fitness: 100.0
# Generation: 315, Best fitness: 100.0
# Generation: 316, Best fitness: 100.0
# Generation: 317, Best fitness: 100.0
# Generation: 318, Best fitness: 100.0
# Generation: 319, Best fitness: 100.0
# Generation: 320, Best fitness: 100.0
# Generation: 321, Best fitness: 100.0
# Generation: 322, Best fitness: 100.0
# Generation: 323, Best fitness: 100.0
# Generation: 324, Best fitness: 100.0
# Generation: 325, Best fitness: 100.0
# Generation: 326, Best fitness: 100.0
# ...
# Generation: 570, Best fitness: 200.0
# Generation: 571, Best fitness: 200.0
# Generation: 572, Best fitness: 200.0
# Generation: 573, Best fitness: 200.0
# Generation: 574, Best fitness: 200.0
# Generation: 575, Best fitness: 200.0
# Generation: 576, Best fitness: 200.0
# Generation: 577, Best fitness: 200.0
# Generation: 578, Best fitness: 200.0
# Generation: 579, Best fitness: 200.0
# Generation: 580, Best fitness: 200.0
# Generation: 581, Best fitness: 200.0
# Generation: 582, Best fitness: 200.0
# Generation: 583, Best fitness: 200.0
# Generation: 584, Best fitness: 200.0
# Generation: 585, Best fitness: 200.0
# Generation: 586, Best fitness: 200.0
# Generation: 587, Best fitness: 200.0
# Generation: 588, Best fitness: 200.0
# Generation: 589, Best fitness: 200.0
# Generation: 590, Best fitness: 200.0
# Generation: 591, Best fitness: 200.0
# Generation: 592, Best fitness: 200.0
# Generation: 593, Best fitness: 200.0
# Generation: 594, Best fitness: 200.0
# Generation: 595, Best fitness: 200.0
# Generation: 596, Best fitness: 200.0
# Generation: 597, Best fitness: 200.0
# Generation: 598, Best fitness: 200.0
# Generation: 599, Best fitness: 200.0
# Generation: 600, Best fitness: 200.0
# Generation: 601, Best fitness: 200.0
# Generation: 602, Best fitness: 200.0
# Generation: 603, Best fitness: 200.0
# Generation: 604, Best fitness: 200.0
# Generation: 605, Best fitness: 200.0
# Generation: 606, Best fitness: 200.0
# Generation: 607, Best fitness: 200.0
# Generation: 608, Best fitness: 200.0
# Generation: 609, Best fitness: 200.0
# Generation: 610, Best fitness: 200.0
# Generation: 611, Best fitness: 200.0
# Generation: 612, Best fitness: 200.0
# Generation: 613, Best fitness: 200.0
# Generation: 614, Best fitness: 200.0
# Generation: 615, Best fitness: 200.0
# Generation: 616, Best fitness: 200.0
# Generation: 617, Best fitness: 200.0
# Generation: 618, Best fitness: 200.0
# Generation: 619, Best fitness: 200.0
# Generation: 620, Best fitness: 200.0
# Generation: 621, Best fitness: 200.0
# Generation: 622, Best fitness: 200.0
# Generation: 623, Best fitness: 250.0
# Generation: 624, Best fitness: 200.0
# Generation: 625, Best fitness: 200.0
# Generation: 626, Best fitness: 200.0
# Generation: 627, Best fitness: 200.0
# Generation: 628, Best fitness: 200.0
# Generation: 629, Best fitness: 200.0
# Generation: 630, Best fitness: 200.0
# Generation: 631, Best fitness: 200.0
# Generation: 632, Best fitness: 200.0
# Generation: 633, Best fitness: 200.0
# Generation: 634, Best fitness: 200.0
# Generation: 635, Best fitness: 200.0
# Generation: 636, Best fitness: 200.0
# Generation: 637, Best fitness: 200.0
# Generation: 638, Best fitness: 200.0
# Generation: 639, Best fitness: 200.0
# Generation: 640, Best fitness: 200.0
# Generation: 641, Best fitness: 200.0
# Generation: 642, Best fitness: 200.0
# Generation: 643, Best fitness: 200.0
# Generation: 644, Best fitness: 200.0
# Generation: 645, Best fitness: 200.0
# Generation: 646, Best fitness: 200.0
# Generation: 647, Best fitness: 200.0
# Generation: 648, Best fitness: 200.0
# Generation: 649, Best fitness: 200.0
# Generation: 650, Best fitness: 200.0
# Generation: 651, Best fitness: 200.0
# Generation: 652, Best fitness: 200.0
# Generation: 653, Best fitness: 200.0
# Generation: 654, Best fitness: 200.0
# Generation: 655, Best fitness: 200.0
# Generation: 656, Best fitness: 200.0
# Generation: 657, Best fitness: 200.0
# Generation: 658, Best fitness: 200.0
# Generation: 659, Best fitness: 200.0
# Generation: 660, Best fitness: 200.0
# Generation: 661, Best fitness: 200.0
# Generation: 662, Best fitness: 200.0
# Generation: 663, Best fitness: 200.0
# Generation: 664, Best fitness: 200.0
# Generation: 665, Best fitness: 200.0
# Generation: 666, Best fitness: 200.0
# Generation: 667, Best fitness: 200.0
# Generation: 668, Best fitness: 200.0
# Generation: 669, Best fitness: 200.0
# Generation: 670, Best fitness: 200.0
# Generation: 671, Best fitness: 200.0
# Generation: 672, Best fitness: 200.0
# Generation: 673, Best fitness: 200.0
# Generation: 674, Best fitness: 200.0
# Generation: 675, Best fitness: 200.0
# Generation: 676, Best fitness: 200.0
# Generation: 677, Best fitness: 200.0
# Generation: 678, Best fitness: 200.0
# Generation: 679, Best fitness: 200.0
# Generation: 680, Best fitness: 200.0
# Generation: 681, Best fitness: 200.0
# Generation: 682, Best fitness: 200.0
# Generation: 683, Best fitness: 200.0
# Generation: 684, Best fitness: 200.0
# Generation: 685, Best fitness: 200.0
# Generation: 686, Best fitness: 200.0
# Generation: 687, Best fitness: 200.0
# Generation: 688, Best fitness: 200.0
# Generation: 689, Best fitness: 200.0
# Generation: 690, Best fitness: 200.0
# Generation: 691, Best fitness: 200.0
# Generation: 692, Best fitness: 200.0
# Generation: 693, Best fitness: 200.0
# Generation: 694, Best fitness: 200.0
# Generation: 695, Best fitness: 200.0
# Generation: 696, Best fitness: 200.0
# Generation: 697, Best fitness: 200.0
# Generation: 698, Best fitness: 200.0
# Generation: 699, Best fitness: 200.0
# Generation: 700, Best fitness: 200.0
# Generation: 701, Best fitness: 200.0
# Generation: 702, Best fitness: 200.0
# Generation: 703, Best fitness: 200.0
# Generation: 704, Best fitness: 200.0
# Generation: 705, Best fitness: 200.0
# Generation: 706, Best fitness: 200.0
# Generation: 707, Best fitness: 200.0
# Generation: 708, Best fitness: 200.0
# Generation: 709, Best fitness: 200.0
# Generation: 710, Best fitness: 200.0
# Generation: 711, Best fitness: 250.0
# Generation: 712, Best fitness: 250.0
# Generation: 713, Best fitness: 250.0
# Generation: 714, Best fitness: 200.0
# Generation: 715, Best fitness: 200.0
# Generation: 716, Best fitness: 200.0
# Generation: 717, Best fitness: 200.0
# Generation: 718, Best fitness: 200.0
# Generation: 719, Best fitness: 200.0
# Generation: 720, Best fitness: 200.0
# Generation: 721, Best fitness: 200.0
# Generation: 722, Best fitness: 200.0
# Generation: 723, Best fitness: 200.0
# Generation: 724, Best fitness: 200.0
# Generation: 725, Best fitness: 200.0
# Generation: 726, Best fitness: 200.0
# Generation: 727, Best fitness: 200.0
# Generation: 728, Best fitness: 200.0
# Generation: 729, Best fitness: 200.0
# Generation: 730, Best fitness: 200.0
# Generation: 731, Best fitness: 200.0
# Generation: 732, Best fitness: 200.0
# Generation: 733, Best fitness: 200.0
# Generation: 734, Best fitness: 200.0
# Generation: 735, Best fitness: 200.0
# Generation: 736, Best fitness: 200.0
# Generation: 737, Best fitness: 200.0
# Generation: 738, Best fitness: 200.0
# Generation: 739, Best fitness: 200.0
# Generation: 740, Best fitness: 200.0
# Generation: 741, Best fitness: 200.0
# Generation: 742, Best fitness: 200.0
# Generation: 743, Best fitness: 200.0
# Generation: 744, Best fitness: 200.0
# Generation: 745, Best fitness: 200.0
# Generation: 746, Best fitness: 250.0
# Generation: 747, Best fitness: 200.0
# Generation: 748, Best fitness: 200.0
# Generation: 749, Best fitness: 200.0
# Generation: 750, Best fitness: 200.0
# Generation: 751, Best fitness: 200.0
# Generation: 752, Best fitness: 200.0
# Generation: 753, Best fitness: 200.0
# Generation: 754, Best fitness: 200.0
# Generation: 755, Best fitness: 200.0
# Generation: 756, Best fitness: 200.0
# Generation: 757, Best fitness: 200.0
# Generation: 758, Best fitness: 200.0
# Generation: 759, Best fitness: 200.0
# Generation: 760, Best fitness: 200.0
# Generation: 761, Best fitness: 200.0
# Generation: 762, Best fitness: 200.0
# Generation: 763, Best fitness: 200.0
# Generation: 764, Best fitness: 200.0
# Generation: 765, Best fitness: 200.0
# Generation: 766, Best fitness: 200.0
# Generation: 767, Best fitness: 200.0
# Generation: 768, Best fitness: 200.0
# Generation: 769, Best fitness: 200.0
# Generation: 770, Best fitness: 250.0
# Generation: 771, Best fitness: 250.0
# Generation: 772, Best fitness: 250.0
# Generation: 773, Best fitness: 250.0
# Generation: 774, Best fitness: 200.0
# Generation: 775, Best fitness: 200.0
# Generation: 776, Best fitness: 200.0
# Generation: 777, Best fitness: 200.0
# Generation: 778, Best fitness: 200.0
# Generation: 779, Best fitness: 200.0
# Generation: 780, Best fitness: 200.0
# Generation: 781, Best fitness: 250.0
# Generation: 782, Best fitness: 250.0
# Generation: 783, Best fitness: 250.0
# Generation: 784, Best fitness: 250.0
# Generation: 785, Best fitness: 250.0
# Generation: 786, Best fitness: 250.0
# Generation: 787, Best fitness: 250.0
# Generation: 788, Best fitness: 250.0
# Generation: 789, Best fitness: 250.0
# Generation: 790, Best fitness: 250.0
# Generation: 791, Best fitness: 250.0
# Generation: 792, Best fitness: 250.0
# Generation: 793, Best fitness: 250.0
# Generation: 794, Best fitness: 250.0
# Generation: 795, Best fitness: 250.0
# Generation: 796, Best fitness: 250.0
# Generation: 797, Best fitness: 250.0
# Generation: 798, Best fitness: 200.0
# Generation: 799, Best fitness: 200.0
# Generation: 800, Best fitness: 250.0
# Generation: 801, Best fitness: 250.0
# Generation: 802, Best fitness: 250.0
# Generation: 803, Best fitness: 250.0
# Generation: 804, Best fitness: 250.0
# Generation: 805, Best fitness: 250.0
# Generation: 806, Best fitness: 200.0
# Generation: 807, Best fitness: 200.0
# Generation: 808, Best fitness: 200.0
# Generation: 809, Best fitness: 200.0
# Generation: 810, Best fitness: 200.0
# Generation: 811, Best fitness: 200.0
# Generation: 812, Best fitness: 200.0
# Generation: 813, Best fitness: 200.0
# Generation: 814, Best fitness: 200.0
# Generation: 815, Best fitness: 200.0
# Generation: 816, Best fitness: 200.0
# Generation: 817, Best fitness: 200.0
# Generation: 818, Best fitness: 200.0
# Generation: 819, Best fitness: 200.0
# Generation: 820, Best fitness: 200.0
# Generation: 821, Best fitness: 200.0
# Generation: 822, Best fitness: 200.0
# Generation: 823, Best fitness: 200.0
# Generation: 824, Best fitness: 200.0
# Generation: 825, Best fitness: 200.0
# Generation: 826, Best fitness: 200.0
# Generation: 827, Best fitness: 200.0
# Generation: 828, Best fitness: 200.0
# Generation: 829, Best fitness: 200.0
# Generation: 830, Best fitness: 200.0
# Generation: 831, Best fitness: 200.0
# Generation: 832, Best fitness: 200.0
# Generation: 833, Best fitness: 200.0
# Generation: 834, Best fitness: 200.0
# Generation: 835, Best fitness: 200.0
# Generation: 836, Best fitness: 200.0
# Generation: 837, Best fitness: 200.0
# Generation: 838, Best fitness: 200.0
# Generation: 839, Best fitness: 200.0
# Generation: 840, Best fitness: 200.0
# Generation: 841, Best fitness: 200.0
# Generation: 842, Best fitness: 200.0
# Generation: 843, Best fitness: 200.0
# Generation: 844, Best fitness: 200.0
# Generation: 845, Best fitness: 200.0
# Generation: 846, Best fitness: 200.0
# Generation: 847, Best fitness: 200.0
# Generation: 848, Best fitness: 200.0
# Generation: 849, Best fitness: 200.0
# Generation: 850, Best fitness: 200.0
# Generation: 851, Best fitness: 200.0
# Generation: 852, Best fitness: 200.0
# Generation: 853, Best fitness: 200.0
# Generation: 854, Best fitness: 200.0
# Generation: 855, Best fitness: 200.0
# Generation: 856, Best fitness: 200.0
# Generation: 857, Best fitness: 200.0
# Generation: 858, Best fitness: 200.0
# Generation: 859, Best fitness: 200.0
# Generation: 860, Best fitness: 200.0
# Generation: 861, Best fitness: 200.0
# Generation: 862, Best fitness: 200.0
# Generation: 863, Best fitness: 200.0
# Generation: 864, Best fitness: 200.0
# Generation: 865, Best fitness: 200.0
# Generation: 866, Best fitness: 200.0
# Generation: 867, Best fitness: 200.0
# Generation: 868, Best fitness: 200.0
# Generation: 869, Best fitness: 200.0
# Generation: 870, Best fitness: 200.0
# Generation: 871, Best fitness: 200.0
# Generation: 872, Best fitness: 200.0
# Generation: 873, Best fitness: 200.0
# Generation: 874, Best fitness: 200.0
# Generation: 875, Best fitness: 200.0
# Generation: 876, Best fitness: 200.0
# Generation: 877, Best fitness: 200.0
# Generation: 878, Best fitness: 200.0
# Generation: 879, Best fitness: 200.0
# Generation: 880, Best fitness: 200.0
# Generation: 881, Best fitness: 200.0
# Generation: 882, Best fitness: 200.0
# Generation: 883, Best fitness: 200.0
# Generation: 884, Best fitness: 200.0
# Generation: 885, Best fitness: 200.0
# Generation: 886, Best fitness: 200.0
# Generation: 887, Best fitness: 200.0
# Generation: 888, Best fitness: 200.0
# Generation: 889, Best fitness: 200.0
# Generation: 890, Best fitness: 200.0
# Generation: 891, Best fitness: 200.0
# Generation: 892, Best fitness: 200.0
# Generation: 893, Best fitness: 200.0
# Generation: 894, Best fitness: 200.0
# Generation: 895, Best fitness: 200.0
# Generation: 896, Best fitness: 200.0
# Generation: 897, Best fitness: 200.0
# Generation: 898, Best fitness: 200.0
# Generation: 899, Best fitness: 200.0
# Generation: 900, Best fitness: 200.0
# Generation: 901, Best fitness: 200.0
# Generation: 902, Best fitness: 250.0
# Generation: 903, Best fitness: 200.0
# Generation: 904, Best fitness: 200.0
# Generation: 905, Best fitness: 200.0
# Generation: 906, Best fitness: 200.0
# Generation: 907, Best fitness: 200.0
# Generation: 908, Best fitness: 200.0
# Generation: 909, Best fitness: 200.0
# Generation: 910, Best fitness: 200.0
# Generation: 911, Best fitness: 200.0
# Generation: 912, Best fitness: 200.0
# Generation: 913, Best fitness: 200.0
# Generation: 914, Best fitness: 200.0
# Generation: 915, Best fitness: 250.0
# Generation: 916, Best fitness: 250.0
# Generation: 917, Best fitness: 250.0
# Generation: 918, Best fitness: 200.0
# Generation: 919, Best fitness: 250.0
# Generation: 920, Best fitness: 250.0
# Generation: 921, Best fitness: 250.0
# Generation: 922, Best fitness: 200.0
# Generation: 923, Best fitness: 200.0
# Generation: 924, Best fitness: 200.0
# Generation: 925, Best fitness: 200.0
# Generation: 926, Best fitness: 200.0
# Generation: 927, Best fitness: 200.0
# Generation: 928, Best fitness: 200.0
# Generation: 929, Best fitness: 200.0
# Generation: 930, Best fitness: 200.0
# Generation: 931, Best fitness: 200.0
# Generation: 932, Best fitness: 250.0
# Generation: 933, Best fitness: 200.0
# Generation: 934, Best fitness: 200.0
# Generation: 935, Best fitness: 200.0
# Generation: 936, Best fitness: 250.0
# Generation: 937, Best fitness: 250.0
# Generation: 938, Best fitness: 250.0
# Generation: 939, Best fitness: 250.0
# Generation: 940, Best fitness: 250.0
# Generation: 941, Best fitness: 250.0
# Generation: 942, Best fitness: 250.0
# Generation: 943, Best fitness: 250.0
# Generation: 944, Best fitness: 200.0
# Generation: 945, Best fitness: 200.0
# Generation: 946, Best fitness: 200.0
# Generation: 947, Best fitness: 200.0
# Generation: 948, Best fitness: 200.0
# Generation: 949, Best fitness: 200.0
# Generation: 950, Best fitness: 200.0
# Generation: 951, Best fitness: 200.0
# Generation: 952, Best fitness: 200.0
# Generation: 953, Best fitness: 200.0
# Generation: 954, Best fitness: 200.0
# Generation: 955, Best fitness: 200.0
# Generation: 956, Best fitness: 200.0
# Generation: 957, Best fitness: 200.0
# Generation: 958, Best fitness: 200.0
# Generation: 959, Best fitness: 200.0
# Generation: 960, Best fitness: 200.0
# Generation: 961, Best fitness: 200.0
# Generation: 962, Best fitness: 200.0
# Generation: 963, Best fitness: 200.0
# Generation: 964, Best fitness: 200.0
# Generation: 965, Best fitness: 200.0
# Generation: 966, Best fitness: 200.0
# Generation: 967, Best fitness: 200.0
# Generation: 968, Best fitness: 200.0
# Generation: 969, Best fitness: 200.0
# Generation: 970, Best fitness: 200.0
# Generation: 971, Best fitness: 200.0
# Generation: 972, Best fitness: 200.0
# Generation: 973, Best fitness: 200.0
# Generation: 974, Best fitness: 200.0
# Generation: 975, Best fitness: 200.0
# Generation: 976, Best fitness: 200.0
# Generation: 977, Best fitness: 200.0
# Generation: 978, Best fitness: 200.0
# Generation: 979, Best fitness: 200.0
# Generation: 980, Best fitness: 200.0
# Generation: 981, Best fitness: 200.0
# Generation: 982, Best fitness: 200.0
# Generation: 983, Best fitness: 200.0
# Generation: 984, Best fitness: 200.0
# Generation: 985, Best fitness: 200.0
# Generation: 986, Best fitness: 200.0
# Generation: 987, Best fitness: 200.0
# Generation: 988, Best fitness: 200.0
# Generation: 989, Best fitness: 200.0
# Generation: 990, Best fitness: 200.0
# Generation: 991, Best fitness: 200.0
# Generation: 992, Best fitness: 200.0
# Generation: 993, Best fitness: 200.0
# Generation: 994, Best fitness: 200.0
# Generation: 995, Best fitness: 200.0
# Generation: 996, Best fitness: 200.0
# Generation: 997, Best fitness: 200.0
# Generation: 998, Best fitness: 200.0
# Generation: 999, Best fitness: 200.0
# Average makespan for task size 1000: 316.4950850491495

# %%
import simpy
import numpy as np

class Server:
    def __init__(self, env, speed=1, latency=0):
        self.env = env
        self.machine = simpy.Resource(env, capacity=1)
        self.latest_task_end_time = 0
        self.speed = speed
        self.latency = latency  # New attribute for latency
        self.expected_end_time = 0

    def process(self, task):
        with self.machine.request() as req:
            yield req
            yield self.env.timeout((task.duration / self.speed) + self.latency)  # Add latency to processing time
            self.latest_task_end_time = self.env.now
            self.expected_end_time = self.env.now + (task.duration / self.speed) + self.latency  # Add latency to expected end time

class Task:
    def __init__(self, duration):
        self.duration = duration

class FitnessFunction:
    def __init__(self, tasks, servers):
        self.tasks = tasks
        self.servers = servers
        self.makespans = {task_duration: [] for task_duration in tasks}  # Store makespans for each task duration

    def __call__(self, solution):
        env = simpy.Environment()
        servers = [Server(env, speed=speed, latency=latency) for speed, latency in self.servers]  # Initialize servers with speed and latency
        task_objects = []

        for task_duration, server_index in zip(self.tasks, solution):
            task = Task(task_duration)
            task_objects.append(task)  # Keep track of task objects
            server = servers[int(server_index)]
            env.process(server.process(task))

        env.run()

        # Store makespan for each task size
        for task in task_objects:
            self.makespans[task.duration].append(server.latest_task_end_time)

        makespan = max(server.latest_task_end_time for server in servers)
        return makespan

class Flower:
    def __init__(self, decision_variables, lower_bound, upper_bound):
        self.position = np.random.uniform(
            low=lower_bound, high=upper_bound, size=decision_variables)
        self.fitness = np.inf


class SimulatedAnnealing:
    def __init__(self, fitness_function, initial_solution, initial_temperature, final_temperature, cooling_rate):
        self.fitness_function = fitness_function
        self.current_solution = initial_solution
        self.current_fitness = self.fitness_function(self.current_solution)
        self.best_solution = self.current_solution
        self.best_fitness = self.current_fitness
        self.temperature = initial_temperature
        self.final_temperature = final_temperature
        self.cooling_rate = cooling_rate

    def accept(self, candidate_fitness):
        if candidate_fitness < self.current_fitness:
            return True
        else:
            delta = self.current_fitness - candidate_fitness
            probability = np.exp(delta / self.temperature)
            return np.random.rand() < probability

    def cool_down(self):
        if self.temperature > self.final_temperature:
            self.temperature *= self.cooling_rate


class FlowerPollination:
    def __init__(self, fitness_function, population_size=100, decision_variables=10, lower_bound=0, upper_bound=1, generations=1000, switch_prob=0.8, gamma=0.1, beta=1.5):
        self.population = [Flower(
            decision_variables, lower_bound, upper_bound) for _ in range(population_size)]
        self.global_best = None
        self.fitness_function = fitness_function
        self.population_size = population_size
        self.decision_variables = decision_variables
        self.lower_bound = lower_bound
        self.upper_bound = upper_bound
        self.generations = generations
        self.switch_prob = switch_prob
        self.gamma = gamma
        self.beta = beta

    def levy_flight(self, beta):
        sigma = (np.math.gamma(1 + beta) * np.sin(np.pi * beta / 2) /
                 (np.math.gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))) ** (1 / beta)
        u = np.random.normal(0, sigma, size=self.decision_variables)
        v = np.random.normal(0, 1, size=self.decision_variables)
        step = u / abs(v) ** (1 / beta)
        return step

    def global_pollination(self, flower):
        step_size = self.gamma * self.levy_flight(self.beta)
        new_position = flower.position + step_size * \
            (flower.position - self.global_best.position)
        return new_position

    def local_pollination(self, flower):
        flower_j = np.random.choice(self.population)
        epsilon = np.random.uniform(
            low=0, high=1, size=self.decision_variables)
        new_position = flower.position + epsilon * \
            (flower_j.position - flower.position)
        return new_position

    def pollination(self, flower):
        r = np.random.uniform(low=0, high=1)
        if r < self.switch_prob:
            new_position = self.global_pollination(flower)
        else:
            new_position = self.local_pollination(flower)
        return np.clip(new_position, self.lower_bound, self.upper_bound)

    def find_global_best(self):
        for flower in self.population:
            if flower.fitness < self.global_best.fitness:
                self.global_best = flower


    def optimize(self):
        self.global_best = self.population[0]
        self.global_best.fitness = self.fitness_function(self.global_best.position)
        sa = SimulatedAnnealing(self.fitness_function, self.global_best.position, initial_temperature=10, final_temperature=0.001, cooling_rate=0.9)

        for g in range(self.generations):
            for flower in self.population:
                flower.fitness = self.fitness_function(flower.position)
                self.find_global_best()

                new_position = self.pollination(flower)
                new_fitness = self.fitness_function(new_position)

                if sa.accept(new_fitness):
                    flower.position = new_position
                    flower.fitness = new_fitness

            sa.cool_down()  # cool down the temperature after each generation
            self.find_global_best()
            print(f"Generation: {g}, Best fitness: {self.global_best.fitness}")

        return self.global_best

# Then when initializing servers, specify both speed and latency.
cloud_servers = [(1, 0.1), (2, 0.1), (3, 0.1), (4, 0.1), (5, 0.1)]  # For cloud servers
edge_servers = [(1, 0.01), (2, 0.01), (3, 0.01), (4, 0.01), (5, 0.01)]  # For edge servers

# Run your optimization for both cloud and edge servers.
for task_size in task_sizes:
    print(f"Optimizing for cloud servers with task size: {task_size}")
    fitness_function = FitnessFunction([task_size], cloud_servers)  # Single task size
    fp = FlowerPollination(fitness_function, decision_variables=1, lower_bound=0, upper_bound=len(servers)-1, generations=100)
    best_flower = fp.optimize()
    print(f"Average makespan for cloud servers with task size {task_size}: {np.mean(fitness_function.makespans[task_size])}")

    print(f"Optimizing for edge servers with task size: {task_size}")
    fitness_function = FitnessFunction([task_size], edge_servers)  # Single task size
    fp = FlowerPollination(fitness_function, decision_variables=1, lower_bound=0, upper_bound=len(servers)-1, generations=100)
    best_flower = fp.optimize()
    print(f"Average makespan for edge servers with task size {task_size}: {np.mean(fitness_function.makespans[task_size])}")
